# %% [markdown]
# # Classificador de Imagens
#
# Classificador de imagens em escala de cinza, utilizando os algoritmos LBP e GLCM como extratores de características.

# %% [markdown]
# ## Carregar as imagens
#
# Carrega as imagens do dataset e as converte para escala de cinza

# %%
import numpy as np
import skimage as ski
import matplotlib.pyplot as plt
from skimage.color import rgb2gray
import importlib
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv('.env', override=True)
# Out:
# True

# %%
# Import the image segmentation tools
import tools.image_tools as it

importlib.reload(it)

from tools.image_tools import (
    segment_image_auto,
    segment_images_by_category_auto,
    calculate_dynamic_k, 
    visualize_image_segmentation_auto,
    merge_image_categories_dicts,
    load_train_images_dict
)

# %%
import warnings

# Suprime warnings do JobLib relacionados ao ResourceTracker
# Evita poluição do output com mensagens irrelevantes
warnings.filterwarnings('ignore', category=UserWarning, module='joblib')
warnings.filterwarnings('ignore', message='.*resource_tracker.*')
warnings.filterwarnings('ignore', message='.*Cannot register.*')

# %%
from typing import Dict, List
import numpy as np

images_directory = "./images/pieces"
image_categories = ["dogs", "cats", "lions", "horses"]
n_examples = 4
NEEDS_RESIZE = int(os.getenv("NEEDS_RESIZE", True))
RESIZE_SIZE = int(os.getenv("RESIZE_SIZE", 512))
ACCEPTED_IMAGES_EXTENSIONS = (".jpg", ".jpeg", ".png")

train_images_by_categories = load_train_images_dict(
    images_directory,
    image_categories,
    ACCEPTED_IMAGES_EXTENSIONS,
    NEEDS_RESIZE,
)


def show_gray_scale_image_examples(
    images: Dict[str, np.ndarray], n: int = 3, label: str = "Example"
) -> None:
    """
    Display grayscale image examples from a dictionary of images.
    
    Args:
        images (Dict[str, np.ndarray]): Dictionary with filename as key and image array as value
        n (int): Number of images to display (default: 3)
        label (str): Label prefix for image titles (default: "Example")
    """
    # Convert dictionary items to list and take first n items
    items = list(images.items())[:n]
    plt.figure(figsize=(10, 10))
    for i, (key, img) in enumerate(items):
        plt.subplot(1, n, i + 1)
        plt.imshow(img, cmap=plt.cm.gray)
        plt.title(f"{label} {key}")
        plt.axis("on")


def show_examples_by_category(
    categories: List[str], 
    images: Dict[str, Dict[str, np.ndarray]], 
    n: int = 3
) -> None:
    """
    Display image examples for each category.
    
    Args:
        categories (List[str]): List of category names
        images (Dict[str, Dict[str, np.ndarray]]): Nested dictionary structure:
                                                  {category: {filename: image_array}}
        n (int): Number of images per category to display (default: 3)
    """
    for category in categories:
        print(f"{category} examples:")
        show_gray_scale_image_examples(images[category], n=n, label=category)
        plt.show()


show_examples_by_category(image_categories, train_images_by_categories, n=n_examples)
# Out:
# dogs examples:
# cats examples:
# lions examples:
# horses examples:

# %% [markdown]
# Mostra o histograma das imagens de exemplo:

# %%
def show_examples_histograms(
    images: Dict[str, np.ndarray], n: int = 3, label: str = "Example"
) -> None:
    """
    Display histograms for a set of grayscale images.
    
    Args:
        images (Dict[str, np.ndarray]): Dictionary with filename as key and image array as value
        n (int): Number of histograms to display (default: 3)
        label (str): Label prefix for histogram titles (default: "Example")
    """
    # Convert dictionary items to list and take first n items
    items = list(images.items())[:n]
    plt.figure(figsize=(20, 10))
    for i, (key, img) in enumerate(items):
        plt.subplot(1, n, i + 1)
        plt.hist(img.ravel(), bins=256)
        plt.title(key)
        plt.axis("on")
        plt.xlabel("Intensidade dos pixels")


def show_examples_histograms_by_category(
    categories: List[str], 
    images: Dict[str, Dict[str, np.ndarray]], 
    n: int = 3
) -> None:
    """
    Display histograms for images from each category.
    
    Args:
        categories (List[str]): List of category names
        images (Dict[str, Dict[str, np.ndarray]]): Nested dictionary structure:
                                                  {category: {filename: image_array}}
        n (int): Number of histograms per category to display (default: 3)
    """
    for category in categories:
        print(f"{category} histograms:")
        show_examples_histograms(images[category], n=n, label=category)
        plt.show()


show_examples_histograms_by_category(
    image_categories, train_images_by_categories, n=n_examples
)
# Out:
# dogs histograms:
# cats histograms:
# lions histograms:
# horses histograms:

# %% [markdown]
# # Segmentação das Imagens
#
# Ao aplicar técnica de Relevância, pretende-se descobrir quais partes, ou regiões, de uma imagem são mais relevantes para o processo de classificação.
#
# O primeiro passo, é segmentar essas imagens em `k` partes.
#
# Num primeiro momento, esse `k` será calculado dinamicamente, de forma a gerar uma quantidade razoável de pedaços, sem muito critério.
#
# Conforme os experimentos avançarem, melhores configurações serão testadas.

# %%
# Get the image segmentation factor from environment variable
# Default to 4 if not set
MIN_K=int(os.getenv('IMAGE_MIN_K', 4))
MAX_K=int(os.getenv('IMAGE_MAX_K', 20))
BASE_SIZE=int(os.getenv('IMAGE_BASE_SIZE', 512))
BASE_K=int(os.getenv('IMAGE_BASE_K', 9))

print(f"MIN_K: {MIN_K}, MAX_K: {MAX_K}, BASE_SIZE: {BASE_SIZE}, BASE_K: {BASE_K}")
# Out:
# MIN_K: 4, MAX_K: 20, BASE_SIZE: 512, BASE_K: 9

# %%
# Teste de segmentação automática com K dinâmico

# Carregue algumas imagens de teste
test_images = {}
for category in image_categories:
    if len(train_images_by_categories[category]) > 0:
        features_qty = list(train_images_by_categories[category].items())[:2]
        for k, v in features_qty:
            test_images[k] = v  # 2 por categoria

print("Teste de K dinâmico:")
for key, image in test_images.items():
    height, width = image.shape

    # Calcular K dinamicamente
    auto_k = calculate_dynamic_k(
        height, width, min_k=MIN_K, max_k=MAX_K, base_size=BASE_SIZE, base_k=BASE_K
    )

    print(f"Imagem {key}: {height}x{width} → K={auto_k}")

    # Segmentar automaticamente
    auto_segmented = segment_image_auto(
        image, min_k=MIN_K, max_k=MAX_K, base_size=BASE_SIZE, base_k=BASE_K
    )  # Cada imagem vira uma matriz de pedaços
    actual_regions = auto_segmented.shape[0] * auto_segmented.shape[1]
    print(
        f"  Resultado: {auto_segmented.shape[0]}x{auto_segmented.shape[1]} grid ({actual_regions} regiões)"
    )

print("\nVisualizando segmentação automática:")
for key, image in test_images.items():
    visualize_image_segmentation_auto(
        image, min_k=MIN_K, max_k=MAX_K, base_size=BASE_SIZE, base_k=BASE_K
    )
# Out:
# Teste de K dinâmico:
# Imagem dog1: 512x512 → K=9
#   Resultado: 3x3 grid (9 regiões)
# Imagem dog10: 512x512 → K=9
#   Resultado: 3x3 grid (9 regiões)
# Imagem cat1: 512x512 → K=9
#   Resultado: 3x3 grid (9 regiões)
# Imagem cat10: 512x512 → K=9
#   Resultado: 3x3 grid (9 regiões)
# Imagem lion1035: 512x512 → K=9
#   Resultado: 3x3 grid (9 regiões)
# Imagem lion1696: 512x512 → K=9
#   Resultado: 3x3 grid (9 regiões)
# Imagem horse1248: 512x512 → K=9
#   Resultado: 3x3 grid (9 regiões)
# Imagem horse1483: 512x512 → K=9
#   Resultado: 3x3 grid (9 regiões)
#
# Visualizando segmentação automática:

# %% [markdown]
# ## Obter conjunto de imagens particionadas
#
# Todas as imagens devem serem particionadas em `K` partes. Inicialmente, a quantidade dessas regiões será calculado dinamicamente.
#
# Após o particionamento serão obtidos dois conjuntos de imagens:
#  * **Imagens originais:** Utilizadas para treinar os especialistas
#  * **Imagens particionadas:** Utilizadas para calcular a relevância da imagem

# %%
segmented_train_images = segment_images_by_category_auto(
    images_by_category=train_images_by_categories,
    min_k=MIN_K,
    max_k=MAX_K,
    base_k=BASE_K,
    base_size=BASE_SIZE,
)

all_images_segmented = merge_image_categories_dicts(segmented_train_images)
# Out:
# Auto-segmenting 30 images from category 'dogs' (K range: 4-20)...
#   Generated average 9.0 regions per image
# dogs: 270 regions total
# Auto-segmenting 30 images from category 'cats' (K range: 4-20)...
#   Generated average 9.0 regions per image
# cats: 270 regions total
# Auto-segmenting 30 images from category 'lions' (K range: 4-20)...
#   Generated average 9.0 regions per image
# lions: 270 regions total
# Auto-segmenting 30 images from category 'horses' (K range: 4-20)...
#   Generated average 9.0 regions per image
# horses: 270 regions total

# %% [markdown]
# ## Ler features já processadas anteriormente

# %%
import files

importlib.reload(files)

from files import load_features_from_files, save_features_to_files, verify_features_files

# %%
features = []
FEATURES_FILES = ['lbp.npy', 'glcm.npy', 'lpq.npy', 'labels.npy']


# Verifica se alguma feature não está escrita em disco
all_features_stored = verify_features_files(FEATURES_FILES)
all_features_stored
# Out:
# False

# %% [markdown]
# ## Extrair a estrutura das imagens de treino com LBP
#
# Cada imagem tem sua própria estrutura. Todavia, imagens de objetos similares, via de regra, terão certa semelhança entre suas estruturas. Imagens de gatos terão uma "textura" similar entre si, supostamente. O que não é esperado ocorrer entre uma imagem de um gato e um cachorro, por exemplo.
#
# Nesse contexto, é possível utilizar o algoritmo **LBP (Local Binary Pattern)** para extrair a estrutura/textura das imagens de treino e agrupá-las em categorias.

# %% [markdown]
# Para visualizar a estrutura computada das imagens pode-se montar um histograma com as informações fornececidas pelo LBP.

# %%
import lbp

importlib.reload(lbp)

from lbp import (
    compute_lbp_for_segments_by_categories,
)

# %%
def show_sample_histograms(histograms: Dict[str, np.ndarray], n=3, label="Example"):
    """
    Display sample histograms from a dictionary of histograms.
    
    Args:
        histograms: Dictionary with name as key and histogram array as value
        n: Number of histograms to display
        label: Label for the plots
    """
    # Get first histogram to determine number of bins
    first_histogram = next(iter(histograms.values()))
    vals = range(len(first_histogram))
    
    plt.figure(figsize=(10, 5))

    for i, (name, sample) in enumerate(list(histograms.items())[:n]):
        plt.subplot(1, n, i + 1)
        plt.bar(vals, sample)
        plt.title(f"{name}")
        plt.axis("on")


def show_sample_histograms_by_category(
    categories: list[str], 
    lbps_dict_histograms: Dict[str, Dict[str, np.ndarray]], 
    n: int = 3
) -> None:
    """
    Display sample histograms for each category.
    
    Args:
        categories: List of category names
        lbps_dict_histograms: Dictionary structure {category: {image_name: features_array}}
        n: Number of samples per category
    """
    for category in categories:
        category_data = lbps_dict_histograms[category]
        
        if not category_data:
            print(f"No data available for category {category}")
            continue
            
        # Get first sample to determine characteristics count
        first_sample = next(iter(category_data.values()))
        
        # Check if it's a single histogram or array of histograms
        if len(first_sample.shape) == 1:
            # Single histogram per image
            x = first_sample.shape[0]
        else:
            # Array of histograms (segmented image case)
            x = first_sample.shape[1]  # Number of features per segment
            
        print(f"Identified {x} characteristics for {category}")
        print(f"{category} histograms:")
        
        # For segmented images, we need to show the first histogram of each image
        display_histograms = {}
        for image_name, features in list(category_data.items())[:n]:
            if len(features.shape) == 1:
                # Single histogram
                display_histograms[image_name] = features
            else:
                # Array of histograms - take the first one
                display_histograms[image_name] = features[0]
        
        show_sample_histograms(display_histograms, n=n, label=category)
        plt.show()


if not all_features_stored:
    # settings for LBP
    radius = 2
    n_pixels = 8

    lbps_by_categories = compute_lbp_for_segments_by_categories(
        image_categories, segmented_train_images, radius, n_pixels
    )

    show_sample_histograms_by_category(
        image_categories, lbps_by_categories, n=n_examples
    )

    features.append(lbps_by_categories)
# Out:
# Identified 59 characteristics for dogs
# dogs histograms:
# Identified 59 characteristics for cats
# cats histograms:
# Identified 59 characteristics for lions
# lions histograms:
# Identified 59 characteristics for horses
# horses histograms:

# %% [markdown]
# ### Calcular matriz GLCM
#
# O primeiro passo do algoritmo GLCM é montar a matriz de níveis de cinza, onde o número de linhas e colunas é igual ao número de níveis de cinza.

# %%
import glcm

from glcm import (
    parallel_calculate_glcm_for_each_category
)

importlib.reload(glcm)
# Out:
# <module 'glcm' from '/home/afmireski/Documentos/BCC/TCC/tcc_image_classification_by_relevance_of_regions/glcm.py'>

# %%
GLCM_DISTANCES = [1, 3, 5]
GLCM_ANGLES = np.deg2rad([0, 90, 180, 270])
GLCM_LEVELS = None
GLCM_FEATURES = [
    "contrast",
    "dissimilarity",
    "homogeneity",
    "ASM",
    "energy",
    "correlation",
]

glcms_by_category = parallel_calculate_glcm_for_each_category(
    image_categories, segmented_train_images, GLCM_DISTANCES, GLCM_ANGLES, GLCM_FEATURES, GLCM_LEVELS
)


features.append(glcms_by_category)

# %% [markdown]
# ### Extrair texturas das matrizes
#
# Após computar as matrizes de nível de cinza, o próximo passo é extrair as características/texturas dessas matrizes, utilizando algumas das técnicas disponíveis: "contrast",    "dissimilarity", "homogeneity", "ASM","energy","correlation".

# %% [markdown]
# Em média são extraídas 72 características de cada imagem, utilizando a configuração escolhida aqui.
#
# Abaixo serão exibidas as características da primeira imagem de cada classe de treino para comparação:

# %%
def show_glcm_features_for_each_category(categories: list, glcms: Dict[str, Dict[str, np.ndarray]]):
    for category in categories:
        category_data = glcms[category]

        if not category_data:
            print(f"No data available for category {category}")
            continue

        first_sample = next(iter(category_data.values()))

        # Check if it's a single histogram or array of histograms
        if len(first_sample.shape) == 1:
            # Single histogram per image
            features_qty = first_sample.shape[0]
        else:
            # Array of histograms (segmented image case)
            features_qty = first_sample.shape[1]  # Number of features per segment

        print(f"Identified {features_qty} GLCM features for {category}")

        image_name, features = list(category_data.items())[:1][0]

        if len(features.shape) == 1:
            # Single glcm
            display_glcm = features
        else:
            # Array of glcms - take the first one
            display_glcm = features[0]

        plt.figure(figsize=(10, 5))
        plt.plot(display_glcm)
        plt.title(f"{image_name} GLCM Features")
        plt.xlabel("Feature")
        plt.ylabel("Value")
    plt.show()

show_glcm_features_for_each_category(image_categories, glcms_by_category)
# Out:
# Identified 72 GLCM features for dogs
# Identified 72 GLCM features for cats
# Identified 72 GLCM features for lions
# Identified 72 GLCM features for horses

# %% [markdown]
# ## Extrair características utilizando LPQ

# %%
import lpq

importlib.reload(lpq)

from lpq import extract_lpq_features_for_each_category

# %%
lpqs_dict = extract_lpq_features_for_each_category(image_categories, segmented_train_images)

features.append(lpqs_dict)

# %% [markdown]
# # Matriz de Características
#
# Dicionários são pouco práticos para se armazenar informações que serão utilizadas para treinar modelos de Aprendizado de Máquina. Nesse contexto, vetores e matrizes são muito mais amplamente utilizados.
# Assim, dado um vetor de `N` rótulos, por exemplo, `images_categories`, é possível imaginar a seguinte estrutura:
# - Um vetor de `N` posições: `images`.
#     - Cada posição do vetor corresponde ao rótulo na mesma posição em `images_categories`.
# - Cada posição contém um array de duas posições:
#     - A primeira posição contém as matriz de características extraídas usando o `LBP`
#     - A segunda posição contém a matriz de características extraídas usando o `GLCM`
#     - A terceira posição contém um vetor de rótulos.
# - Cada coluna da matriz é uma característica.
# - Cada linha da matriz corresponde a uma imagem.

# %%
import tools.data as tdt
importlib.reload(tdt)

from tools.data import (
    generate_texture_dicts,
    show_features_summary
)

# %%
(sets, labels, true_images_labels) = generate_texture_dicts(
    image_categories, features[0], features[1], features[2]
)
# Out:
# Categoria: dogs, Número de elementos: 30
# Categoria: cats, Número de elementos: 30
# Categoria: lions, Número de elementos: 30
# Categoria: horses, Número de elementos: 30
# Categoria: dogs, Número de elementos: 30
# Categoria: cats, Número de elementos: 30
# Categoria: lions, Número de elementos: 30
# Categoria: horses, Número de elementos: 30
# Categoria: dogs, Número de elementos: 30
# Categoria: cats, Número de elementos: 30
# Categoria: lions, Número de elementos: 30
# Categoria: horses, Número de elementos: 30

# %% [markdown]
# Ao final do processo, é esperado que para cada imagem sejam identificadas 59 características utilizando o LBP, 72 utilizando o GLCM e 256 utilizando o LPQ.
# Uma função que quantifica e resume as informações das imagens de entrada existe abaixo.

# %%
show_features_summary(sets, labels)
# Out:
# ==================================================
# RESUMO DOS CONJUNTOS DE FEATURES
# ==================================================
# 📊 Total de imagens: 120
# 🔧 Total de conjuntos gerados: 7
# 📋 Labels únicos: {'lions', 'cats', 'dogs', 'horses'}
#
# 🔹 LBP:
#    📁 Imagens: 120
#    🧩 Segmentos por imagem: 9
#    🧱 Total de segmentos do conjunto: 1080
#    🎯 Features por segmento: 59
#    📈 Total features por imagem: 531
#
# 🔹 GLCM:
#    📁 Imagens: 120
#    🧩 Segmentos por imagem: 9
#    🧱 Total de segmentos do conjunto: 1080
#    🎯 Features por segmento: 72
#    📈 Total features por imagem: 648
#
# 🔹 LPQ:
#    📁 Imagens: 120
#    🧩 Segmentos por imagem: 9
#    🧱 Total de segmentos do conjunto: 1080
#    🎯 Features por segmento: 256
#    📈 Total features por imagem: 2304
#
# 🔹 LBP+GLCM:
#    📁 Imagens: 120
#    🧩 Segmentos por imagem: 9
#    🧱 Total de segmentos do conjunto: 1080
#    🎯 Features por segmento: 131
#    📈 Total features por imagem: 1179
#
# 🔹 LBP+LPQ:
#    📁 Imagens: 120
#    🧩 Segmentos por imagem: 9
#    🧱 Total de segmentos do conjunto: 1080
#    🎯 Features por segmento: 315
#    📈 Total features por imagem: 2835
#
# 🔹 GLCM+LPQ:
#    📁 Imagens: 120
#    🧩 Segmentos por imagem: 9
#    🧱 Total de segmentos do conjunto: 1080
#    🎯 Features por segmento: 328
#    📈 Total features por imagem: 2952
#
# 🔹 LBP+GLCM+LPQ:
#    📁 Imagens: 120
#    🧩 Segmentos por imagem: 9
#    🧱 Total de segmentos do conjunto: 1080
#    🎯 Features por segmento: 387
#    📈 Total features por imagem: 3483
#
# ==================================================

# %%
# Limpeza de variáveis desnecessárias após o cálculo das features
# Uma vez que as features estão calculadas e salvas, podemos liberar memória
# removendo variáveis intermediárias que não serão mais utilizadas

import gc  # Garbage collector

print("Limpando variáveis desnecessárias...")
print(f"Variáveis antes da limpeza: {len(locals())} variáveis locais")

# Variáveis de dados intermediários que podem ser removidas
variables_to_clean = [
    # Dados de segmentação (já processados)
    'segmented_train_images',
    
    # Dados intermediários de features por categoria (já consolidados)
    'lbps_by_categories',
    'glcms_by_category', 
    'lpq_features_dict',
    
    # Variáveis antigas que não existem mais
    'lbps_dict_categories', 
    'lbps_histograms_by_categories',
    'glcm_features_by_category',
    
    # Imagens de teste usadas para demonstração
    'test_images',
    
    # Variáveis temporárias do processo de merge (se existirem)
    'merge_lbp', 'merge_glcm', 'merge_lpq', 'merge_labels',
    'data',
    
    # Arrays de features individuais antigos (estrutura mudou)
    'X_lbp', 'X_glcm', 'X_lpq',
    
    # Conjuntos antigos (estrutura mudou para combined_sets)
    'set_lbp', 'set_glcm', 'set_lpq', 'set_lbp_glcm', 
    'set_lbp_lpq', 'set_glcm_lpq', 'set_lbp_glcm_lpq',
    
    # Outras variáveis temporárias
    'auto_k', 'auto_segmented', 'actual_regions',
    'height', 'width', 'i', 'image',
    
    # Variáveis de configuração temporárias
    'radius', 'n_pixels', 'n_examples'
]

# Conta quantas variáveis foram realmente removidas
removed_count = 0
for var_name in variables_to_clean:
    if var_name in locals():
        del locals()[var_name]
        removed_count += 1
        print(f"  ✓ Removida: {var_name}")

# Remove também variáveis globais se existirem
for var_name in variables_to_clean:
    if var_name in globals():
        del globals()[var_name]

# Força a coleta de lixo para liberar memória imediatamente
gc.collect()

print(f"\n✓ Limpeza concluída!")
print(f"  - {removed_count} variáveis removidas")
print(f"  - Memória liberada pela coleta de lixo")
print(f"  - Variáveis após limpeza: {len(locals())} variáveis locais")

# Mostra as principais variáveis que permanecem (estrutura atualizada)
essential_vars = [
    'image_categories', 'train_images_by_categories',
    'combined_sets', 'labels', 'all_features_stored',
    'GLCM_DISTANCES', 'GLCM_ANGLES', 'GLCM_FEATURES'
]

print("\n📋 Principais variáveis mantidas:")
for var in essential_vars:
    if var in locals():
        if hasattr(locals()[var], 'shape'):
            print(f"  ✓ {var}: {type(locals()[var]).__name__} {getattr(locals()[var], 'shape', '')}")
        elif isinstance(locals()[var], (list, dict)):
            print(f"  ✓ {var}: {type(locals()[var]).__name__} (tamanho: {len(locals()[var])})")
        else:
            print(f"  ✓ {var}: {type(locals()[var]).__name__}")

print("\n💡 Variáveis limpas com sucesso! Agora você pode prosseguir com o treinamento dos modelos.")
print("🔄 Nova estrutura: combined_sets contém todos os conjuntos de features combinados.")
# Out:
# Limpando variáveis desnecessárias...
# Variáveis antes da limpeza: 148 variáveis locais
#   ✓ Removida: segmented_train_images
#   ✓ Removida: lbps_by_categories
#   ✓ Removida: glcms_by_category
#   ✓ Removida: test_images
#   ✓ Removida: auto_k
#   ✓ Removida: auto_segmented
#   ✓ Removida: actual_regions
#   ✓ Removida: height
#   ✓ Removida: width
#   ✓ Removida: image
#   ✓ Removida: radius
#   ✓ Removida: n_pixels
#   ✓ Removida: n_examples
#
# ✓ Limpeza concluída!
#   - 13 variáveis removidas
#   - Memória liberada pela coleta de lixo
#   - Variáveis após limpeza: 138 variáveis locais
#
# 📋 Principais variáveis mantidas:
#   ✓ image_categories: list (tamanho: 4)
#   ✓ train_images_by_categories: dict (tamanho: 4)
#   ✓ labels: list (tamanho: 120)
#   ✓ all_features_stored: bool
#   ✓ GLCM_DISTANCES: list (tamanho: 3)
#   ✓ GLCM_ANGLES: ndarray (4,)
#   ✓ GLCM_FEATURES: list (tamanho: 6)
#
# 💡 Variáveis limpas com sucesso! Agora você pode prosseguir com o treinamento dos modelos.
# 🔄 Nova estrutura: combined_sets contém todos os conjuntos de features combinados.

# %% [markdown]
# # Dividir o conjunto de dados
#
# Para esse projeto, será utilizada a técnica de validação cruzada em K-Partições, visando obter uma ideia melhor do desempenho do modelo, treinando-o com todos os dados.
# Após alguns testes, foi escolhido `K=x`.
#
# A ideia, é que hajam vários modelos, cada um treinado com um tipo de conjunto de dados:
# - LBP
# - GLCM
# - LPQ
# - LBP + GLCM
# - LBP + LPQ
# - GLCM + LPQ
# - LBP + GLCM + LBP
#
# Para facilitar o armazenamento, cada conjunto será um vetor com as seguintes características:
# - Primeira posição será o conjunto total das features.
# - Segunda posição será os rótulos

# %%
# Importa bilbliotecas que serão necessárias para dividir e padronizar dos dados
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Número de folds para a validação cruzada
K_FOLDS = 5

# %%
# Extraí os conjuntos e os labels da estrutura de dados:
[X_lbp, X_glcm, X_lpq, X_lbp_glcm, X_lbp_lpq, X_glcm_lpq, X_lbp_glcm_lpq] = sets
    
set_lbp = (X_lbp, labels)
set_glcm = (X_glcm, labels)
set_lpq = (X_lpq, labels)
set_lbp_glcm = (X_lbp_glcm, labels)
set_lbp_lpq = (X_lbp_lpq, labels)
set_glcm_lpq = (X_glcm_lpq, labels)
set_lbp_glcm_lpq = (X_lbp_glcm_lpq, labels)

# %% [markdown]
# # Conjuntos de Dados Especialistas
#
# Um especialista é alguém especializado em reconhecer algo, no contexto desse projeto, cada especialista deve ser capaz de reconhecer uma dada classe com maestria.
#
# Nesse cenário, são necessários conjuntos de dados customizados para treiná-los.
#
# Um conjunto de dados especialista possuí somente dois rótulos: `classe` e `não classe`.
#
# Então, para cada conjunto de características extraídos acima, serão gerados N conjuntos de dados especialistas, um para cada classe.

# %%
import tools.specialists as sp

importlib.reload(sp)

from tools.specialists import (
    build_specialist_set_for_many_classes
)

# %%
print(f"Classes: {image_categories}")

sp_lbp_sets = build_specialist_set_for_many_classes(X_lbp, labels, image_categories)
sp_glcm_sets = build_specialist_set_for_many_classes(X_glcm, labels, image_categories)
sp_lpq_sets = build_specialist_set_for_many_classes(X_lpq, labels, image_categories)
sp_lbp_glcm_sets = build_specialist_set_for_many_classes(X_lbp_glcm, labels, image_categories)
sp_lbp_lpq_sets = build_specialist_set_for_many_classes(X_lbp_lpq, labels, image_categories)
sp_glcm_lpq_sets = build_specialist_set_for_many_classes(X_glcm_lpq, labels, image_categories)
sp_lbp_glcm_lpq_sets = build_specialist_set_for_many_classes(X_lbp_glcm_lpq, labels, image_categories)
# Out:
# Classes: ['dogs', 'cats', 'lions', 'horses']
# Class dogs: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class dogs
# Class features shape: (9, 59)
# Class labels shape: 30
# No class features shape: (9, 59)
# No class labels shape: 90
# ===============
# Class cats: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class cats
# Class features shape: (9, 59)
# Class labels shape: 30
# No class features shape: (9, 59)
# No class labels shape: 90
# ===============
# Class lions: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class lions
# Class features shape: (9, 59)
# Class labels shape: 30
# No class features shape: (9, 59)
# No class labels shape: 90
# ===============
# Class horses: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class horses
# Class features shape: (9, 59)
# Class labels shape: 30
# No class features shape: (9, 59)
# No class labels shape: 90
# ===============
# Class dogs: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class dogs
# Class features shape: (9, 72)
# Class labels shape: 30
# No class features shape: (9, 72)
# No class labels shape: 90
# ===============
# Class cats: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class cats
# Class features shape: (9, 72)
# Class labels shape: 30
# No class features shape: (9, 72)
# No class labels shape: 90
# ===============
# Class lions: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class lions
# Class features shape: (9, 72)
# Class labels shape: 30
# No class features shape: (9, 72)
# No class labels shape: 90
# ===============
# Class horses: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class horses
# Class features shape: (9, 72)
# Class labels shape: 30
# No class features shape: (9, 72)
# No class labels shape: 90
# ===============
# Class dogs: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class dogs
# Class features shape: (9, 256)
# Class labels shape: 30
# No class features shape: (9, 256)
# No class labels shape: 90
# ===============
# Class cats: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class cats
# Class features shape: (9, 256)
# Class labels shape: 30
# No class features shape: (9, 256)
# No class labels shape: 90
# ===============
# Class lions: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class lions
# Class features shape: (9, 256)
# Class labels shape: 30
# No class features shape: (9, 256)
# No class labels shape: 90
# ===============
# Class horses: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class horses
# Class features shape: (9, 256)
# Class labels shape: 30
# No class features shape: (9, 256)
# No class labels shape: 90
# ===============
# Class dogs: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class dogs
# Class features shape: (9, 131)
# Class labels shape: 30
# No class features shape: (9, 131)
# No class labels shape: 90
# ===============
# Class cats: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class cats
# Class features shape: (9, 131)
# Class labels shape: 30
# No class features shape: (9, 131)
# No class labels shape: 90
# ===============
# Class lions: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class lions
# Class features shape: (9, 131)
# Class labels shape: 30
# No class features shape: (9, 131)
# No class labels shape: 90
# ===============
# Class horses: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class horses
# Class features shape: (9, 131)
# Class labels shape: 30
# No class features shape: (9, 131)
# No class labels shape: 90
# ===============
# Class dogs: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class dogs
# Class features shape: (9, 315)
# Class labels shape: 30
# No class features shape: (9, 315)
# No class labels shape: 90
# ===============
# Class cats: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class cats
# Class features shape: (9, 315)
# Class labels shape: 30
# No class features shape: (9, 315)
# No class labels shape: 90
# ===============
# Class lions: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class lions
# Class features shape: (9, 315)
# Class labels shape: 30
# No class features shape: (9, 315)
# No class labels shape: 90
# ===============
# Class horses: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class horses
# Class features shape: (9, 315)
# Class labels shape: 30
# No class features shape: (9, 315)
# No class labels shape: 90
# ===============
# Class dogs: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class dogs
# Class features shape: (9, 328)
# Class labels shape: 30
# No class features shape: (9, 328)
# No class labels shape: 90
# ===============
# Class cats: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class cats
# Class features shape: (9, 328)
# Class labels shape: 30
# No class features shape: (9, 328)
# No class labels shape: 90
# ===============
# Class lions: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class lions
# Class features shape: (9, 328)
# Class labels shape: 30
# No class features shape: (9, 328)
# No class labels shape: 90
# ===============
# Class horses: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class horses
# Class features shape: (9, 328)
# Class labels shape: 30
# No class features shape: (9, 328)
# No class labels shape: 90
# ===============
# Class dogs: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class dogs
# Class features shape: (9, 387)
# Class labels shape: 30
# No class features shape: (9, 387)
# No class labels shape: 90
# ===============
# Class cats: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class cats
# Class features shape: (9, 387)
# Class labels shape: 30
# No class features shape: (9, 387)
# No class labels shape: 90
# ===============
# Class lions: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class lions
# Class features shape: (9, 387)
# Class labels shape: 30
# No class features shape: (9, 387)
# No class labels shape: 90
# ===============
# Class horses: 30 positive samples, 90 negative samples
# ===============
# Specialist summary for class horses
# Class features shape: (9, 387)
# Class labels shape: 30
# No class features shape: (9, 387)
# No class labels shape: 90
# ===============

# %% [markdown]
# # Divisão dos Dados
#
# Para garantir que todos os modelos utilizarão os mesmos dados, é ideal realizar o split das FOLDs antes. Então, a ideia é gerar K tuplas, onde cada elemento corresponde a uma fold.

# %%
importlib.reload(tdt)

from tools.data import (
    prepare_sets_for_classification,
)

# %%
from sklearn.model_selection import StratifiedKFold

def split_data_in_folds_sklearn(dataset, k_folds=5):
    skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

    [X, y] = dataset

    folds = []

    for train_index, test_index in skf.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        folds.append(((X_train, y_train), (X_test, y_test)))

    return folds

# %% [markdown]
# Extraímos as folds de cada um dos conjuntos de dados que temos:

# %%
final_sp_lbp_sets = prepare_sets_for_classification(sp_lbp_sets, k_folds=K_FOLDS)
final_sp_glcm_sets = prepare_sets_for_classification(sp_glcm_sets, k_folds=K_FOLDS)
final_sp_lpq_sets = prepare_sets_for_classification(sp_lpq_sets, k_folds=K_FOLDS)
final_sp_lbp_glcm_sets = prepare_sets_for_classification(sp_lbp_glcm_sets, k_folds=K_FOLDS)
final_sp_lbp_lpq_sets = prepare_sets_for_classification(sp_lbp_lpq_sets, k_folds=K_FOLDS)
final_sp_glcm_lpq_sets = prepare_sets_for_classification(sp_glcm_lpq_sets, k_folds=K_FOLDS)
final_sp_lbp_glcm_lpq_sets = prepare_sets_for_classification(sp_lbp_glcm_lpq_sets, k_folds=K_FOLDS)
# Out:
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 59), y(864,)
#   ✅ Teste: 216 imagens → X(216, 59), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 72), y(864,)
#   ✅ Teste: 216 imagens → X(216, 72), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 256), y(864,)
#   ✅ Teste: 216 imagens → X(216, 256), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 131), y(864,)
#   ✅ Teste: 216 imagens → X(216, 131), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 315), y(864,)
#   ✅ Teste: 216 imagens → X(216, 315), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 328), y(864,)
#   ✅ Teste: 216 imagens → X(216, 328), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 🎉 5 folds processados com sucesso!
# 📊 Total imagens classe: 30
# 📊 Total imagens não-classe: 90
# 🔄 Dividindo em 5 folds...
#   Fold 0: 6 classe, 18 não-classe
#   Fold 1: 6 classe, 18 não-classe
#   Fold 2: 6 classe, 18 não-classe
#   Fold 3: 6 classe, 18 não-classe
#   Fold 4: 6 classe, 18 não-classe
#
# 🔧 Construindo fold 0...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 1...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 2...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 3...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🔧 Construindo fold 4...
#   ✅ Treino: 24 classe + 72 não-classe = 96
#   ✅ Teste: 6 classe + 18 não-classe = 24
#
# 🎉 5 folds construídos com sucesso!
# 🔄 Convertendo folds para formato de classificação...
#
# 📂 Processando fold 0...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 1...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 2...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 3...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 📂 Processando fold 4...
#   🏋️ Processando dados de treino...
#   🧪 Processando dados de teste...
#   ✅ Treino: 864 imagens → X(864, 387), y(864,)
#   ✅ Teste: 216 imagens → X(216, 387), y(216,)
#
# 🎉 5 folds processados com sucesso!

# %% [markdown]
# # Modelo KNN
#
# Um dos algoritmos supervisionados mais simples é o KNN (K-Nearest Neighbor), K Vizinhos mais Próximos em tradução livre.
# Ele parte da ideia de que dados que pertencem a um mesmo conjunto estarão próximos entre si, então, é seguro presumir que um novo dado pertencerá ao conjunto com mais elementos similares na região.
# Basicamente é o ditado: `"Diga-me com quem andas e te direi quem és."`.
#
# Partindo para uma explicação mais técnica, o `k` é um valor que define a zona de busca a ser considerada a partir do novo elemento.
# Dado esse novo elemento, será computada a distância entre o novo registro e cada ponto do conjunto, registrando-as num vetor de distância e relacionando-as com o label correspondente.
# Depois, esse vetor será ordenado, tendo com base as distâncias. Indo dos mais próximos para os mais distantes.
# Após a ordenação, será utilizado o valor de `k` para selecionar os `k` primeiros elementos do vetor, fazendo o cálculo de frequência para cada categoria.
# A categoria com maior frequência será a escolhida como categoria do novo elemento.
#
# ## Sobre o valor de K
# - Se `k` for muito pequeno (`k=1`), a classificação pode ser sensível a ruídos.
# - Se `k` for muito grande, podem ser incluídos elementos de outras classes.
# - `k` ímpares garantem que não haverá empates.
#
# ## Sobre o cálculo de distâncias
# É possível mudar a fórmula do cálculo da distância, pois dependendo do conjunto de dados, certas fórmulas se saem melhores do que outras. Alguns exemplos:
# - Euclidiana
# - Manhattan
# - City Block

# %%
# Importa as bibliotecas do KNN
from sklearn.neighbors import KNeighborsClassifier

# Bibliotecas úteis para treinamento dos modelos
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline


import utils

importlib.reload(utils)

from utils import show_predict_infos

# %% [markdown]
# Uma boa predição depende dos parâmetros utilizados, nesse sentido, é desejado utilizar sempre os melhores parâmetros para se obter o melhor resultado possível. É para descobrir quais são esses parâmetros que serve o conjunto de validação.

# %%
K_ARRAY = [1, 3, 5, 7, 9]
DISTANCE_METRICS = ["euclidean", "manhattan", "minkowski"]

def tune_knn(k_array, distance_metrics):

    knn = KNeighborsClassifier()

    # Lista com as combinações de hiperparâmetros
    parameters = {
        "knn__n_neighbors": k_array,
        "knn__metric": distance_metrics
    }

    pipe = Pipeline([
        ("scaler", StandardScaler()),
        ("knn", knn)
    ])

    model = GridSearchCV(pipe, parameters, n_jobs=-1)


    return model

print("Tunando parâmetros do KNN...")
base_knn = tune_knn(K_ARRAY, DISTANCE_METRICS)
# Out:
# Tunando parâmetros do KNN...

# %% [markdown]
# # Modelo Random Forest (RF)

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

import utils
from utils import show_predict_infos
importlib.reload(utils)
# Out:
# <module 'utils' from '/home/afmireski/Documentos/BCC/TCC/tcc_image_classification_by_relevance_of_regions/utils.py'>

# %% [markdown]
# ## Tunamento do modelo

# %%
N_ESTIMATORS = [100, 200] # [100, 150, 200, 400]
MIN_SAMPLES_LEAFS = [3, 10, 15, 30]
MIN_SAMPLES_SPLITS = [2, 4, 16, 40]
MAX_DEPTHS = [None, 3, 8] # [None, 2, 3, 4, 5, 8, 12]
MAX_FEATURES = ["sqrt"] # ["sqrt", "log2", 0, 2, 0.5, None]
MAX_SAMPLES = [None] # [None, 0.6, 0.8]
CRITERIONS = ["gini", "entropy"]
CLASS_WEIGHT = [None, "balanced_subsample"] # [None, "balanced_subsample"]


def tune_rf(
    n_estimators,
    min_samples_leaf,
    min_samples_split,
    max_depth,
    max_features,
    max_samples,
    criterions,
    class_weight,
):
    rf = RandomForestClassifier(n_jobs=-1, random_state=42)

    # Lista com as combinações de hiperparâmetros
    parameters = {
        "rf__n_estimators": n_estimators,
        "rf__min_samples_leaf": min_samples_leaf,
        "rf__min_samples_split": min_samples_split,
        "rf__max_depth": max_depth,
        "rf__max_features": max_features,
        "rf__max_samples": max_samples,
        "rf__criterion": criterions,
        "rf__class_weight": class_weight,
    }

    pipe = Pipeline([("scaler", StandardScaler()), ("rf", rf)])

    model = GridSearchCV(pipe, parameters, n_jobs=-1)

    return model


print("Tunando parâmetros do Random Forest...")
base_rf = tune_rf(
    N_ESTIMATORS,
    MIN_SAMPLES_LEAFS,
    MIN_SAMPLES_SPLITS,
    MAX_DEPTHS,
    MAX_FEATURES,
    MAX_SAMPLES,
    CRITERIONS,
    CLASS_WEIGHT,
)
# Out:
# Tunando parâmetros do Random Forest...

# %% [markdown]
# # SVM

# %%
# Importa as bibliotecas da SVM
from sklearn.svm import SVC

from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline

import utils
from utils import show_predict_infos
importlib.reload(utils)
# Out:
# <module 'utils' from '/home/afmireski/Documentos/BCC/TCC/tcc_image_classification_by_relevance_of_regions/utils.py'>

# %%
# Hiperparâmetros da SVM:
# Originais
# KERNELS = ['rbf', 'linear', 'poly', 'sigmoid']
# C = [0.1, 1, 10, 100, 1000]
# GAMMA = [2e-5, 2e-3, 2e-1, "auto", "scale"]
# DEGREE = [2, 3, 4, 5]
# COEF0 = [0, 0.1, 0.5, 1, 5, 10]

# Simplificado
KERNELS = ['rbf']
C = [0.1, 1, 10, 100, 1000]
GAMMA = [2e-5, 2e-3, 2e-1, "auto", "scale"]

# %%
def tune_svm(
    kernels,
    c_array,
    gamma_array,
    # degree_array,
    # coef0_array,
):
    svm = SVC(probability=True, random_state=42)

    # Lista com as combinações de hiperparâmetros
    parameters = {
        "svm__kernel": kernels,
        "svm__C": c_array,
        "svm__gamma": gamma_array,
        # "svm__degree": degree_array,
        # "svm__coef0": coef0_array,
    }

    pipe = Pipeline([
        ("scaler", StandardScaler()),
        ("svm", svm)
    ])

    model = GridSearchCV(pipe, parameters, n_jobs=-1)

    return model

print("Tunando SVM...")
base_svm = tune_svm(
    KERNELS,
    C,
    GAMMA,
    # DEGREE,
    # COEF0,
)
# Out:
# Tunando SVM...

# %% [markdown]
# # Relevância

# %%
import tools.relevance as tr
import utils as ut
importlib.reload(tr)
importlib.reload(ut)

from tools.relevance import relevance_technique, generate_relevance_heatmaps, export_relevance_results_to_csv

from utils import show_confusion_matrix, show_metrics

# %% [markdown]
# ## KNN

# %%
print("🚀 === CALCULANDO RELEVÂNCIA DOS MODELOS KNN ===")

class_names = image_categories
base_name = 'KNN'

print("\n📊 Calculando relevância LBP...")
relevance_results_knn_lbp = relevance_technique(
    base_model=base_knn,
    specialist_sets=final_sp_lbp_sets,
    class_names=class_names,
    model_name=f"{base_name}-LBP",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, knn_lbp_max_relevances, _, _, _, (knn_lbp_true_y, knn_lbp_predicted_y), knn_lbp_relevance_metrics = relevance_results_knn_lbp

show_metrics(knn_lbp_relevance_metrics, title=f"{base_name} LBP")
show_confusion_matrix(knn_lbp_true_y, knn_lbp_predicted_y, title=f"{base_name} LBP - Confusion Matrix", cmap='Blues')
generate_relevance_heatmaps(
    max_relevances=knn_lbp_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lbp",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_knn_lbp,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LBP"
)
# Out:
# 🚀 === CALCULANDO RELEVÂNCIA DOS MODELOS KNN ===
#
# 📊 Calculando relevância LBP...
# 🚀 Iniciando treinamento de especialistas KNN-LBP
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: KNN-LBP-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 3}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: KNN-LBP-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 1}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: KNN-LBP-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: KNN-LBP-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas KNN-LBP concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas KNN LBP:
#    📊 Acurácia: 78.3333%
#    📊 F1: 78.1828%
#    📊 Recall: 78.3333%
#    📊 Precision: 78.8934%
# ----------------------------------------
# /home/afmireski/Documentos/BCC/TCC/tcc_image_classification_by_relevance_of_regions/tools/relevance.py:199: RuntimeWarning: invalid value encountered in divide
#   norm_probs = probs / probs.sum(axis=1, keepdims=True)
# 💾 Matriz de confusão salva em: results/confusion_matrixs/knn_lbp___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: knn_lbp
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=nan, max=nan
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.027, max=0.260
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.245, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.072, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.097, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.021, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.264, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.093, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.062, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.111, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.034, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.060, max=0.309
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.167, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.073, max=0.412
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.004, max=0.481
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.030, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.053, max=0.397
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.061, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.189, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=0.582
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.371
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.315, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.072, max=0.588
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.072, max=0.485
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.505
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.006, max=0.487
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=0.327
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.056, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.028, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=0.392
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.016, max=0.446
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.136, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.132, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.030, max=0.547
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.025, max=0.264
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.007, max=0.580
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.045, max=0.361
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.093, max=0.588
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.072, max=0.522
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.018, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=0.317
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.140, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.034, max=0.309
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.136, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.033, max=0.582
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.166, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=0.582
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.018, max=0.464
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=0.538
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=0.374
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.003, max=0.196
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.121, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.018, max=0.481
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.087, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.035, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.002, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.052, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.173, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.037, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.149, max=0.446
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.005, max=0.284
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.032, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.019, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.274, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.286, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=0.392
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.073, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=0.354
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.002, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.063, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.015, max=0.658
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.018, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.286, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.124, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.032, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.033, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.019, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.284, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.196, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.018, max=0.481
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.027, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.028, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.119, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=0.446
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.096, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=0.485
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.284, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.092, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.108, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.141, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.138, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.154, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.193, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.123, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=0.582
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.027, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.121, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.139, max=0.658
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.199, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.077, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.315, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/knn_lbp/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: KNN_LBP
#    📁 Arquivo: results/csv_exports/knn_lbp_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/knn_lbp_results.csv
# ==================================================
# 'results/csv_exports/knn_lbp_results.csv'

# %%
# Treina especialistas para GLCM
print("\n📊 Calculando relevância GLCM...")
relevance_results_knn_glcm = relevance_technique(
    base_model=base_knn,
    specialist_sets=final_sp_glcm_sets,
    class_names=class_names,
    model_name=f"{base_name}-GLCM",
    k_folds=K_FOLDS,
    true_labels=true_images_labels,
)

(
    _,
    _,
    _,
    knn_glcm_max_relevances,
    _,
    _,
    _,
    (knn_glcm_true_y, knn_glcm_predicted_y),
    knn_glcm_relevance_metrics,
) = relevance_results_knn_glcm

show_metrics(knn_glcm_relevance_metrics, title="KNN GLCM")
show_confusion_matrix(
    knn_glcm_true_y,
    knn_glcm_predicted_y,
    title="KNN GLCM - Confusion Matrix",
    cmap="Blues",
)
generate_relevance_heatmaps(
    max_relevances=knn_glcm_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_glcm",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_knn_glcm,
    true_labels=true_images_labels,
    model_name=f"{base_name}_GLCM"
)
# Out:
# 📊 Calculando relevância GLCM...
# 🚀 Iniciando treinamento de especialistas KNN-GLCM
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: KNN-GLCM-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: KNN-GLCM-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 1}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: KNN-GLCM-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: KNN-GLCM-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 5}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas KNN-GLCM concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas KNN GLCM:
#    📊 Acurácia: 78.3333%
#    📊 F1: 78.0919%
#    📊 Recall: 78.3333%
#    📊 Precision: 78.7652%
# ----------------------------------------
# 💾 Matriz de confusão salva em: results/confusion_matrixs/knn_glcm___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: knn_glcm
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=0.619
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.040, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.103, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=0.412
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.040, max=0.503
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.003, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.137, max=0.547
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.003, max=0.332
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.056, max=0.310
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.073, max=0.374
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.013, max=0.309
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.018, max=0.420
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.146, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.205, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.139, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=0.392
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.527
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.053, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.126, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.045, max=0.582
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.016, max=0.412
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=0.503
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.107, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.083, max=0.619
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=0.535
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.036, max=0.461
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.163, max=0.582
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.149, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.163, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.250, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.052, max=0.327
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.051, max=0.619
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.119, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.033, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.231, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.134, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.019, max=0.588
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.007, max=0.538
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.205, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.118, max=0.374
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.083, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.027, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.361
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.092, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.045, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.144, max=0.582
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.032, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.013, max=0.321
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.021, max=0.547
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=0.374
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.051, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.018, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.163, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.045, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.289, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.045, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.196, max=0.309
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.037, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.115, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.083, max=0.371
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.254, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.132, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.132, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.138, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.013, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.318, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.250, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.003, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.315, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.025, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.098, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.005, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.063, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.111, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.220, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.224, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.142, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.037, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.111, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.028, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.284, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.315, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.135, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.151, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.083, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.147, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.100, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.020, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.481, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.361, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/knn_glcm/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: KNN_GLCM
#    📁 Arquivo: results/csv_exports/knn_glcm_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/knn_glcm_results.csv
# ==================================================
# 'results/csv_exports/knn_glcm_results.csv'

# %%
# Calcula relevância para LPQ
print("\n📊 Calculando relevância LPQ...")
relevance_results_knn_lpq = relevance_technique(
    base_model=base_knn,
    specialist_sets=final_sp_lpq_sets,
    class_names=class_names,
    model_name=f"{base_name}-LPQ",
    k_folds=K_FOLDS,
    true_labels=true_images_labels,
)

(
    _,
    _,
    _,
    knn_lpq_max_relevances,
    _,
    _,
    _,
    (knn_lpq_true_y, knn_lpq_predicted_y),
    knn_lpq_relevance_metrics,
) = relevance_results_knn_lpq

show_metrics(knn_lpq_relevance_metrics, title="KNN LPQ")
show_confusion_matrix(
    knn_lpq_true_y,
    knn_lpq_predicted_y,
    title="KNN LPQ - Confusion Matrix",
    cmap="Blues",
)
generate_relevance_heatmaps(
    max_relevances=knn_lpq_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lpq",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_knn_lpq,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LPQ"
)
# Out:
# 📊 Calculando relevância LPQ...
# 🚀 Iniciando treinamento de especialistas KNN-LPQ
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: KNN-LPQ-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: KNN-LPQ-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: KNN-LPQ-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: KNN-LPQ-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 1}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas KNN-LPQ concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas KNN LPQ:
#    📊 Acurácia: 80.8333%
#    📊 F1: 80.8300%
#    📊 Recall: 80.8333%
#    📊 Precision: 81.8514%
# ----------------------------------------
# 💾 Matriz de confusão salva em: results/confusion_matrixs/knn_lpq___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: knn_lpq
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.315
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.052, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.079, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=0.658
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=0.361
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.091, max=0.547
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.065, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.091, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.003, max=0.392
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=0.361
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.022, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.068, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=0.371
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.020, max=0.582
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=0.392
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.274, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.167, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.137, max=0.503
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.077, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.065, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.016, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.175, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=0.374
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.004, max=0.461
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.394
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.082, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.037, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.005, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.125, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.016, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.154, max=0.464
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.018, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.658
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.149, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.003, max=0.355
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.173, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.132, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.005, max=0.658
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=0.446
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.070, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.082, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.091, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.170, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.006, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.125, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.091, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.144, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=0.485
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.037, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=0.374
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.211, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.105, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.021, max=0.241
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.335, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.070, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.079, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.136, max=0.469
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.103, max=0.481
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.098, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.082, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.025, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.129, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.122, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.211, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.013, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.309, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.035, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.229, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.098, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.034, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.103, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.073, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.033, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.007, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.087, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.119, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.093, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.098, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.033, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.018, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.190, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.046, max=0.424
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.121, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.036, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.083, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.274, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/knn_lpq/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: KNN_LPQ
#    📁 Arquivo: results/csv_exports/knn_lpq_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/knn_lpq_results.csv
# ==================================================
# 'results/csv_exports/knn_lpq_results.csv'

# %%
# Calcula relevância para LBP+GLCM
print("\n📊 Calculando relevância LBP+GLCM...")
relevance_results_knn_lbp_glcm = relevance_technique(
    base_model=base_knn,
    specialist_sets=final_sp_lbp_glcm_sets,
    class_names=class_names,
    model_name=f"{base_name}-LBP+GLCM",
    k_folds=K_FOLDS,
    true_labels=true_images_labels,
)

(
    _,
    _,
    _,
    knn_lbp_glcm_max_relevances,
    _,
    _,
    _,
    (knn_lbp_glcm_true_y, knn_lbp_glcm_predicted_y),
    knn_lbp_glcm_relevance_metrics,
) = relevance_results_knn_lbp_glcm

show_metrics(knn_lbp_glcm_relevance_metrics, title="KNN LBP+GLCM")
show_confusion_matrix(
    knn_lbp_glcm_true_y,
    knn_lbp_glcm_predicted_y,
    title="KNN LBP+GLCM - Confusion Matrix",
    cmap="Blues",
)
generate_relevance_heatmaps(
    max_relevances=knn_lbp_glcm_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lbp_glcm",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_knn_lbp_glcm,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LBP_GLCM"
)
# Out:
# 📊 Calculando relevância LBP+GLCM...
# 🚀 Iniciando treinamento de especialistas KNN-LBP+GLCM
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: KNN-LBP+GLCM-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: KNN-LBP+GLCM-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: KNN-LBP+GLCM-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: KNN-LBP+GLCM-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 3}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas KNN-LBP+GLCM concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas KNN LBP+GLCM:
#    📊 Acurácia: 81.6667%
#    📊 F1: 81.4810%
#    📊 Recall: 81.6667%
#    📊 Precision: 82.5047%
# ----------------------------------------
# 💾 Matriz de confusão salva em: results/confusion_matrixs/knn_lbp_glcm___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: knn_lbp_glcm
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.077, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.008, max=0.298
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.124, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.145, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.210, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.125, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.019, max=0.619
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.159, max=0.527
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.079, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.406
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.096, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.082, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.144, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.119, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.100, max=0.503
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=0.485
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.145, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.000, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.019, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.091, max=0.503
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.165, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.250, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.028, max=0.332
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.136, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.022, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.485
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.046, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.118, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.073, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.108, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.107, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.067, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.172, max=0.588
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.136, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.211, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.082, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.037, max=0.339
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=0.588
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.164, max=0.643
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.146, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.016, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.228, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.111, max=0.547
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.173, max=0.588
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.073, max=0.406
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.131, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.085, max=0.446
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.079, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.109, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.096, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.135, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.028, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.019, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.105, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.091, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.131, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.124, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.374, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.021, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.131, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.019, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.166, max=0.412
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.374, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.025, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.115, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.124, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.132, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.301, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.301, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.588
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.122, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.027, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.009, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.093, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.271, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.094, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.107, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.030, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.304, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.177, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.110, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.107, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.099, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.117, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.020, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.154, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.136, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.083, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.105, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.107, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.085, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.270, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.298, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/knn_lbp_glcm/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: KNN_LBP_GLCM
#    📁 Arquivo: results/csv_exports/knn_lbp_glcm_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/knn_lbp_glcm_results.csv
# ==================================================
# 'results/csv_exports/knn_lbp_glcm_results.csv'

# %%
# Calcula relevância para LBP+LPQ
print("\n📊 Calculando relevância LBP+LPQ...")
relevance_results_knn_lbp_lpq = relevance_technique(
    base_model=base_knn,
    specialist_sets=final_sp_lbp_lpq_sets,
    class_names=class_names,
    model_name=f"{base_name}-LBP+LPQ",
    k_folds=K_FOLDS,
    true_labels=true_images_labels,
)

(
    _,
    _,
    _,
    knn_lbp_lpq_max_relevances,
    _,
    _,
    _,
    (knn_lbp_lpq_true_y, knn_lbp_lpq_predicted_y),
    knn_lbp_lpq_relevance_metrics,
) = relevance_results_knn_lbp_lpq

show_metrics(knn_lbp_lpq_relevance_metrics, title="KNN LBP+LPQ")
show_confusion_matrix(
    knn_lbp_lpq_true_y,
    knn_lbp_lpq_predicted_y,
    title="KNN LBP+LPQ - Confusion Matrix",
    cmap="Blues",
)
generate_relevance_heatmaps(
    max_relevances=knn_lbp_lpq_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lbp_lpq",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_knn_lbp_lpq,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LBP_LPQ"
)
# Out:
# 📊 Calculando relevância LBP+LPQ...
# 🚀 Iniciando treinamento de especialistas KNN-LBP+LPQ
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: KNN-LBP+LPQ-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 1}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 5}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: KNN-LBP+LPQ-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: KNN-LBP+LPQ-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: KNN-LBP+LPQ-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas KNN-LBP+LPQ concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas KNN LBP+LPQ:
#    📊 Acurácia: 80.8333%
#    📊 F1: 80.8237%
#    📊 Recall: 80.8333%
#    📊 Precision: 81.1832%
# ----------------------------------------
# 💾 Matriz de confusão salva em: results/confusion_matrixs/knn_lbp_lpq___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: knn_lbp_lpq
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.043, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=0.309
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.123, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.043, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.073, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.240, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.094, max=0.658
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.025, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.079, max=0.643
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.149, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.126, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.190, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=0.643
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=0.538
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.487
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.107, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.201, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.256, max=0.527
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.213, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.110, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.087, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.199, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.049, max=0.469
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.347
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.141, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.189, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.037, max=0.643
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=0.326
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=0.658
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.005, max=0.446
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.079, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.051, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.547
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.102, max=0.424
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.045, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.129, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.079, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.240, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=0.481
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.163, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.067, max=0.547
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=0.522
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.099, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.006, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.128, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.124, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.167, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.065, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.013, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.274, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.284, max=0.547
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.165, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.092, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.021, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=0.643
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.361, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.087, max=0.424
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.020, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.033, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=0.461
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.136, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.689, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.005, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.259, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.016, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.044, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.115, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.211, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.446, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.091, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.264, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.066, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.114, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.321, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.315, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.136, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.138, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.034, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.025, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.129, max=0.481
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.435, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.098, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.119, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.264, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.255, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/knn_lbp_lpq/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: KNN_LBP_LPQ
#    📁 Arquivo: results/csv_exports/knn_lbp_lpq_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/knn_lbp_lpq_results.csv
# ==================================================
# 'results/csv_exports/knn_lbp_lpq_results.csv'

# %%
# Calcula relevância para GLCM+LPQ
print("\n📊 Calculando relevância GLCM+LPQ...")
relevance_results_knn_glcm_lpq = relevance_technique(
    base_model=base_knn,
    specialist_sets=final_sp_glcm_lpq_sets,
    class_names=class_names,
    model_name=f"{base_name}-GLCM+LPQ",
    k_folds=K_FOLDS,
    true_labels=true_images_labels,
)

(
    _,
    _,
    _,
    knn_glcm_lpq_max_relevances,
    _,
    _,
    _,
    (knn_glcm_lpq_true_y, knn_glcm_lpq_predicted_y),
    knn_glcm_lpq_relevance_metrics,
) = relevance_results_knn_glcm_lpq

show_metrics(knn_glcm_lpq_relevance_metrics, title="KNN GLCM+LPQ")
show_confusion_matrix(
    knn_glcm_lpq_true_y,
    knn_glcm_lpq_predicted_y,
    title="KNN GLCM+LPQ - Confusion Matrix",
    cmap="Blues",
)
generate_relevance_heatmaps(
    max_relevances=knn_glcm_lpq_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_glcm_lpq",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_knn_glcm_lpq,
    true_labels=true_images_labels,
    model_name=f"{base_name}_GLCM_LPQ"
)
# Out:
# 📊 Calculando relevância GLCM+LPQ...
# 🚀 Iniciando treinamento de especialistas KNN-GLCM+LPQ
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: KNN-GLCM+LPQ-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: KNN-GLCM+LPQ-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 1}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: KNN-GLCM+LPQ-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: KNN-GLCM+LPQ-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas KNN-GLCM+LPQ concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas KNN GLCM+LPQ:
#    📊 Acurácia: 81.6667%
#    📊 F1: 81.4771%
#    📊 Recall: 81.6667%
#    📊 Precision: 83.9043%
# ----------------------------------------
# /home/afmireski/Documentos/BCC/TCC/tcc_image_classification_by_relevance_of_regions/tools/relevance.py:199: RuntimeWarning: invalid value encountered in divide
#   norm_probs = probs / probs.sum(axis=1, keepdims=True)
# 💾 Matriz de confusão salva em: results/confusion_matrixs/knn_glcm_lpq___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: knn_glcm_lpq
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.067, max=0.435
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.304, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.141, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.131, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.188, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.032, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=0.435
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.092, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.034, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.122, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.435
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.145, max=0.522
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.146, max=0.580
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.090, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.250, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.003, max=0.282
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.035, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.102, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.250, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=0.503
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.469
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.107, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.128, max=0.469
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.098, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.327, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.245, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.135, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.208, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.079, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.162, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.157, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.161, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.481, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.032, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.397, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.122, max=0.503
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.018, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.061, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.020, max=0.469
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.105, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.099, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.070, max=0.547
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.098, max=0.424
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=0.522
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.165, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.123, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.125, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.070, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.139, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.004, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.274, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.235, max=0.341
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.098, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.036, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=0.392
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=nan, max=nan
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.149, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.100, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.015, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.063, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.033, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.008, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.073, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.135, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.074, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.121, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.013, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.044, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.270, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.250, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.087, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.119, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.270, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.245, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.170, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.487, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.006, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.135, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.022, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.121, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.015, max=0.588
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.174, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.135, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.327, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.643, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/knn_glcm_lpq/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: KNN_GLCM_LPQ
#    📁 Arquivo: results/csv_exports/knn_glcm_lpq_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/knn_glcm_lpq_results.csv
# ==================================================
# 'results/csv_exports/knn_glcm_lpq_results.csv'

# %%
# Calcula relevância para LBP+GLCM+LPQ
print("\n📊 Calculando relevância LBP+GLCM+LPQ...")
relevance_results_knn_lbp_glcm_lpq = relevance_technique(
    base_model=base_knn,
    specialist_sets=final_sp_lbp_glcm_lpq_sets,
    class_names=class_names,
    model_name=f"{base_name}-LBP+GLCM+LPQ",
    k_folds=K_FOLDS,
    true_labels=true_images_labels,
)

(
    _,
    _,
    _,
    knn_lbp_glcm_lpq_max_relevances,
    _,
    _,
    _,
    (knn_lbp_glcm_lpq_true_y, knn_lbp_glcm_lpq_predicted_y),
    knn_lbp_glcm_lpq_relevance_metrics,
) = relevance_results_knn_lbp_glcm_lpq

show_metrics(knn_lbp_glcm_lpq_relevance_metrics, title="KNN LBP+GLCM+LPQ")
show_confusion_matrix(
    knn_lbp_glcm_lpq_true_y,
    knn_lbp_glcm_lpq_predicted_y,
    title="KNN LBP+GLCM+LPQ - Confusion Matrix",
    cmap="Blues",
)
generate_relevance_heatmaps(
    max_relevances=knn_lbp_glcm_lpq_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lbp_glcm_lpq",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_knn_lbp_glcm_lpq,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LBP_GLCM_LPQ"
)
# Out:
# 📊 Calculando relevância LBP+GLCM+LPQ...
# 🚀 Iniciando treinamento de especialistas KNN-LBP+GLCM+LPQ
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: KNN-LBP+GLCM+LPQ-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 9}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: KNN-LBP+GLCM+LPQ-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 5}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: KNN-LBP+GLCM+LPQ-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 9}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: KNN-LBP+GLCM+LPQ-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 7}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 3}
# Melhores parâmetros: {'knn__metric': 'euclidean', 'knn__n_neighbors': 1}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas KNN-LBP+GLCM+LPQ concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas KNN LBP+GLCM+LPQ:
#    📊 Acurácia: 83.3333%
#    📊 F1: 83.0910%
#    📊 Recall: 83.3333%
#    📊 Precision: 85.8626%
# ----------------------------------------
# 💾 Matriz de confusão salva em: results/confusion_matrixs/knn_lbp_glcm_lpq___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: knn_lbp_glcm_lpq
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=0.503
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.007, max=0.318
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.118, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.125, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.071, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.171, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.098, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.208, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.264, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.212, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.137, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.108, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.087, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.007, max=0.412
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.063, max=0.336
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.170, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.161, max=0.658
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=0.392
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.140, max=0.582
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=0.538
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.036, max=0.233
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=0.658
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=0.446
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.085, max=0.315
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=0.547
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.119, max=0.428
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.073, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.003, max=0.446
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.147, max=0.582
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.133, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.068, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=0.582
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=0.619
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.111, max=0.424
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.146, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.077, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.145, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.111, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.166, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.125, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=0.461
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=0.619
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.049, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.077, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.140, max=0.658
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.149, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.204, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.247, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.189, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.135, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.149, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.212, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=0.412
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.161, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=0.446
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.108, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.156, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.019, max=0.619
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.280, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.190, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.016, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.111, max=0.658
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.204, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.041, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.048, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.144, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.019, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.036, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.041, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.123, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.040, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.140, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.020, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.121, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.082, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.098, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.096, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.019, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.332, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.392, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.096, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.111, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.016, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.096, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.046, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.503, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/knn_lbp_glcm_lpq/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: KNN_LBP_GLCM_LPQ
#    📁 Arquivo: results/csv_exports/knn_lbp_glcm_lpq_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/knn_lbp_glcm_lpq_results.csv
# ==================================================
# 'results/csv_exports/knn_lbp_glcm_lpq_results.csv'

# %%
print("\n🎉 === CÁLCULO DE RELEVÂNCIA KNN CONCLUÍDO ===")
print("✅ Relevância calculada para todos os 7 conjuntos de features")
print("📊 Métricas e matrizes de confusão geradas para cada combinação")
# Out:
# 🎉 === CÁLCULO DE RELEVÂNCIA KNN CONCLUÍDO ===
# ✅ Relevância calculada para todos os 7 conjuntos de features
# 📊 Métricas e matrizes de confusão geradas para cada combinação

# %% [markdown]
# ## SVM

# %%
print("🚀 === CALCULANDO RELEVÂNCIA DOS MODELOS SVM ===")

class_names = image_categories
base_name = 'SVM'

print("\n📊 Calculando relevância LBP...")
relevance_results_svm_lbp = relevance_technique(
    base_model=base_svm,
    specialist_sets=final_sp_lbp_sets,
    class_names=class_names,
    model_name=f"{base_name}-LBP",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, svm_lbp_max_relevances, _, _, _, (svm_lbp_true_y, svm_lbp_predicted_y), svm_lbp_relevance_metrics = relevance_results_svm_lbp

show_metrics(svm_lbp_relevance_metrics, title="SVM LBP")
show_confusion_matrix(svm_lbp_true_y, svm_lbp_predicted_y, title="SVM LBP - Confusion Matrix", cmap='Reds')
generate_relevance_heatmaps(
    max_relevances=svm_lbp_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lbp",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_svm_lbp,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LBP"
)
# Out:
# 🚀 === CALCULANDO RELEVÂNCIA DOS MODELOS SVM ===
#
# 📊 Calculando relevância LBP...
# 🚀 Iniciando treinamento de especialistas SVM-LBP
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: SVM-LBP-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: SVM-LBP-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: SVM-LBP-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: SVM-LBP-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas SVM-LBP concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas SVM LBP:
#    📊 Acurácia: 86.6667%
#    📊 F1: 86.6114%
#    📊 Recall: 86.6667%
#    📊 Precision: 86.9345%
# ----------------------------------------
# 💾 Matriz de confusão salva em: results/confusion_matrixs/svm_lbp___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: svm_lbp
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.006, max=0.506
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.406
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=0.695
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.075, max=0.492
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.059, max=0.852
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.072, max=0.534
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.033, max=0.594
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.125, max=0.516
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.048, max=0.548
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.200, max=0.812
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.123, max=0.415
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.016, max=0.710
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.009, max=0.317
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.122, max=0.379
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=0.356
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.006, max=0.587
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.037, max=0.581
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.060, max=0.527
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.444
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.059, max=0.382
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.603
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.126, max=0.724
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.054, max=0.820
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=0.543
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.122, max=0.806
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.100, max=0.350
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=0.541
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.117, max=0.651
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.105, max=0.413
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.088, max=0.398
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.008, max=0.392
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.060, max=0.508
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.041, max=0.441
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.041, max=0.573
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.047, max=0.413
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=0.662
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.067, max=0.497
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.272
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.070, max=0.368
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=0.629
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.107, max=0.561
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.130, max=0.305
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=0.688
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.037, max=0.326
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.054, max=0.419
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.064, max=0.493
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=0.474
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.044, max=0.522
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=0.292
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.054, max=0.542
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=0.466
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=0.551
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.129, max=0.558
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.070, max=0.683
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.072, max=0.444
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.064, max=0.739
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.005, max=0.587
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=0.727
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.070, max=0.687
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.138, max=0.452
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.051, max=0.638
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=0.538
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.661
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.209, max=0.415
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.044, max=0.858
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=0.426
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.036, max=0.296
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.147, max=0.433
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=0.776
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=0.231
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.018, max=0.602
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.133, max=0.827
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.130, max=0.596
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.038, max=0.712
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.187, max=0.384
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=0.554
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.027, max=0.731
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=0.448
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.013, max=0.371
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.142, max=0.490
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.052, max=0.768
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.033, max=0.553
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.168, max=0.543
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=0.606
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.056, max=0.413
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.053, max=0.820
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.086, max=0.592
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.022, max=0.866
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=0.583
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.169, max=0.797
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.065, max=0.920
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.041, max=0.756
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.008, max=0.375
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.035, max=0.779
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.063, max=0.583
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.008, max=0.787
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.077, max=0.435
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.162, max=0.585
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=0.464
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.124, max=0.681
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.041, max=0.233
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.063, max=0.795
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.036, max=0.705
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.112, max=0.787
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.043, max=0.769
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=0.664
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.074, max=0.772
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.041, max=0.669
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=0.769
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.138, max=0.788
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.036, max=0.782
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.085, max=0.496
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.159, max=0.602
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.085, max=0.311
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.112, max=0.563
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=0.485
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.062, max=0.468
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.324, max=0.796
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/svm_lbp/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: SVM_LBP
#    📁 Arquivo: results/csv_exports/svm_lbp_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/svm_lbp_results.csv
# ==================================================
# 'results/csv_exports/svm_lbp_results.csv'

# %%
print("\n📊 Calculando relevância GLCM...")
relevance_results_svm_glcm = relevance_technique(
    base_model=base_svm,
    specialist_sets=final_sp_glcm_sets,
    class_names=class_names,
    model_name=f"{base_name}-GLCM",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, svm_glcm_max_relevances, _, _, _, (svm_glcm_true_y, svm_glcm_predicted_y), svm_glcm_relevance_metrics = relevance_results_svm_glcm

show_metrics(svm_glcm_relevance_metrics, title="SVM GLCM")
show_confusion_matrix(svm_glcm_true_y, svm_glcm_predicted_y, title="SVM GLCM - Confusion Matrix", cmap='Reds')
generate_relevance_heatmaps(
    max_relevances=svm_glcm_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_glcm",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_svm_glcm,
    true_labels=true_images_labels,
    model_name=f"{base_name}_GLCM"
)
# Out:
# 📊 Calculando relevância GLCM...
# 🚀 Iniciando treinamento de especialistas SVM-GLCM
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: SVM-GLCM-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: SVM-GLCM-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: SVM-GLCM-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 1, 'svm__gamma': 0.2, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1, 'svm__gamma': 0.2, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1, 'svm__gamma': 0.2, 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: SVM-GLCM-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas SVM-GLCM concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas SVM GLCM:
#    📊 Acurácia: 82.5000%
#    📊 F1: 82.4259%
#    📊 Recall: 82.5000%
#    📊 Precision: 82.6371%
# ----------------------------------------
# 💾 Matriz de confusão salva em: results/confusion_matrixs/svm_glcm___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: svm_glcm
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.045, max=0.617
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.054, max=0.630
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.093, max=0.271
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.047, max=0.399
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.038, max=0.599
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.109, max=0.714
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=0.587
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.093, max=0.806
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.175, max=0.561
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.007, max=0.577
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.049, max=0.445
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.093, max=0.338
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.085, max=0.732
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.067, max=0.495
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.114, max=0.394
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=0.301
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.034, max=0.418
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.098, max=0.402
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.141, max=0.372
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.060, max=0.349
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.093, max=0.417
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.110, max=0.388
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.094, max=0.536
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.132, max=0.734
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.039, max=0.643
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.096, max=0.891
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=0.739
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=0.616
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.122, max=0.591
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.061, max=0.377
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.081, max=0.512
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.045, max=0.442
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.044, max=0.211
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.155, max=0.570
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.020, max=0.260
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.142, max=0.449
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=0.229
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=0.764
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.083, max=0.263
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.159, max=0.361
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.278, max=0.866
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=0.499
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.073, max=0.433
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.045, max=0.366
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.088, max=0.378
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=0.335
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.403
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.115, max=0.427
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.021, max=0.540
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.109, max=0.223
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.063, max=0.267
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.133, max=0.471
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.052, max=0.381
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=0.467
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.170, max=0.588
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.121, max=0.360
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.063, max=0.746
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.063, max=0.560
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=0.159
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.110, max=0.289
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.146, max=0.585
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.513
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.190, max=0.551
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=0.592
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.065, max=0.636
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.164, max=0.609
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.057, max=0.563
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.157, max=0.861
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.282, max=0.867
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.147, max=0.675
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.091, max=0.900
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.032, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.124, max=0.541
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.077, max=0.418
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.022, max=0.509
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.131, max=0.544
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.277, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.027, max=0.772
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.051, max=0.393
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=0.873
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.013, max=0.925
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.032, max=0.746
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.140, max=0.755
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.025, max=0.680
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.179, max=0.585
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.209, max=0.765
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.230, max=0.643
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.094, max=0.573
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=0.710
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.175, max=0.656
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.165, max=0.761
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.126, max=0.941
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.013, max=0.945
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.051, max=0.951
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.449
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=0.841
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.054, max=0.766
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.047, max=0.977
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.305, max=0.652
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.038, max=0.471
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.009, max=0.829
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.040, max=0.293
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.833
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.085, max=0.820
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.037, max=0.886
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.082, max=1.000
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.048, max=0.763
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.217, max=0.847
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.107, max=0.973
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.033, max=0.983
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.009, max=0.979
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.166, max=0.793
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.035, max=0.833
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.121, max=0.910
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.657
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.102, max=0.640
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=0.892
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.143, max=0.805
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.251, max=0.871
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/svm_glcm/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: SVM_GLCM
#    📁 Arquivo: results/csv_exports/svm_glcm_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/svm_glcm_results.csv
# ==================================================
# 'results/csv_exports/svm_glcm_results.csv'

# %%
print("\n📊 Calculando relevância LPQ...")
relevance_results_svm_lpq = relevance_technique(
    base_model=base_svm,
    specialist_sets=final_sp_lpq_sets,
    class_names=class_names,
    model_name=f"{base_name}-LPQ",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, svm_lpq_max_relevances, _, _, _, (svm_lpq_true_y, svm_lpq_predicted_y), svm_lpq_relevance_metrics = relevance_results_svm_lpq

show_metrics(svm_lpq_relevance_metrics, title="SVM LPQ")
show_confusion_matrix(svm_lpq_true_y, svm_lpq_predicted_y, title="SVM LPQ - Confusion Matrix", cmap='Reds')
generate_relevance_heatmaps(
    max_relevances=svm_lpq_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lpq",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_svm_lpq,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LPQ"
)
# Out:
# 📊 Calculando relevância LPQ...
# 🚀 Iniciando treinamento de especialistas SVM-LPQ
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: SVM-LPQ-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: SVM-LPQ-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: SVM-LPQ-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: SVM-LPQ-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas SVM-LPQ concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas SVM LPQ:
#    📊 Acurácia: 86.6667%
#    📊 F1: 86.6008%
#    📊 Recall: 86.6667%
#    📊 Precision: 86.8495%
# ----------------------------------------
# 💾 Matriz de confusão salva em: results/confusion_matrixs/svm_lpq___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: svm_lpq
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=0.721
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=0.432
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.060, max=0.846
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.035, max=0.501
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.128, max=0.809
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.087, max=0.550
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=0.717
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.120, max=0.835
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.061, max=0.624
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.151, max=0.769
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.107, max=0.609
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.064, max=0.756
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.081, max=0.427
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.139, max=0.361
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.118, max=0.418
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.041, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.022, max=0.805
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.153, max=0.480
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.059, max=0.548
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=0.643
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=0.568
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.007, max=0.700
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.185, max=0.844
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.113, max=0.780
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.624
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.157, max=0.743
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.124, max=0.709
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.060, max=0.828
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.004, max=0.778
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.067, max=0.273
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.045, max=0.547
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.023, max=0.559
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=0.441
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=0.643
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.088, max=0.600
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.184, max=0.708
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.088, max=0.546
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.039, max=0.502
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.068, max=0.465
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.102, max=0.602
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.217, max=0.776
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.118, max=0.780
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.182, max=0.840
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.066, max=0.514
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=0.717
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.048, max=0.542
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.027, max=0.390
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.189, max=0.697
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.199, max=0.568
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.178, max=0.467
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=0.447
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.061, max=0.398
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.162, max=0.453
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.046, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.045, max=0.676
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.126, max=0.590
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.604
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.098, max=0.679
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.008, max=0.760
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.179, max=0.600
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.125, max=0.851
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.190, max=0.453
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=0.537
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.071, max=0.518
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.202, max=0.703
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.192, max=0.605
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.161, max=0.757
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.048, max=0.820
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.030, max=0.251
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.083, max=0.355
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=0.540
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.090, max=0.254
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.092, max=0.838
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.094, max=0.592
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.184, max=0.750
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.421
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.019, max=0.507
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.212, max=0.768
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.149, max=0.702
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.025, max=0.556
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.114, max=0.728
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.151, max=0.781
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.567
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.109, max=0.887
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.250, max=0.767
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.033, max=0.883
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.259, max=0.830
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.116, max=0.839
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.123, max=0.750
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.117, max=0.835
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.241, max=0.703
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.085, max=0.662
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.033, max=0.787
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.009, max=0.806
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.085, max=0.707
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.055, max=0.782
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=0.669
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.109, max=0.913
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.071, max=0.796
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=0.809
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.060, max=0.655
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=0.680
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.070, max=0.694
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.175, max=0.852
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.085, max=0.594
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.186, max=0.866
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.160, max=0.886
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.021, max=0.786
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.025, max=0.887
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.015, max=0.922
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.030, max=0.853
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=0.822
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.059, max=0.721
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.063, max=0.369
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.181, max=0.890
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.087, max=0.796
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.021, max=0.691
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.028, max=0.462
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.812
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.180, max=0.700
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/svm_lpq/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: SVM_LPQ
#    📁 Arquivo: results/csv_exports/svm_lpq_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/svm_lpq_results.csv
# ==================================================
# 'results/csv_exports/svm_lpq_results.csv'

# %%
print("\n📊 Calculando relevância LBP+GLCM...")
relevance_results_svm_lbp_glcm = relevance_technique(
    base_model=base_svm,
    specialist_sets=final_sp_lbp_glcm_sets,
    class_names=class_names,
    model_name=f"{base_name}-LBP+GLCM",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, svm_lbp_glcm_max_relevances, _, _, _, (svm_lbp_glcm_true_y, svm_lbp_glcm_predicted_y), svm_lbp_glcm_relevance_metrics = relevance_results_svm_lbp_glcm

show_metrics(svm_lbp_glcm_relevance_metrics, title="SVM LBP+GLCM")
show_confusion_matrix(svm_lbp_glcm_true_y, svm_lbp_glcm_predicted_y, title="SVM LBP+GLCM - Confusion Matrix", cmap='Reds')
generate_relevance_heatmaps(
    max_relevances=svm_lbp_glcm_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lbp_glcm",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_svm_lbp_glcm,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LBP_GLCM"
)
# Out:
# 📊 Calculando relevância LBP+GLCM...
# 🚀 Iniciando treinamento de especialistas SVM-LBP+GLCM
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: SVM-LBP+GLCM-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: SVM-LBP+GLCM-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: SVM-LBP+GLCM-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: SVM-LBP+GLCM-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 2e-05, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas SVM-LBP+GLCM concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas SVM LBP+GLCM:
#    📊 Acurácia: 89.1667%
#    📊 F1: 89.1894%
#    📊 Recall: 89.1667%
#    📊 Precision: 89.2834%
# ----------------------------------------
# 💾 Matriz de confusão salva em: results/confusion_matrixs/svm_lbp_glcm___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: svm_lbp_glcm
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.128, max=0.506
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.132, max=0.445
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.112, max=0.705
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=0.414
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.158, max=0.877
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.200, max=0.591
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.603
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.132, max=0.769
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.077, max=0.729
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.082, max=0.692
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.133, max=0.509
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.140, max=0.904
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.115, max=0.541
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.194, max=0.646
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.173, max=0.292
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.048, max=0.746
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.112, max=0.715
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=0.813
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.133, max=0.419
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.068, max=0.703
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.070, max=0.667
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.202, max=0.582
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.057, max=0.535
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.097, max=0.607
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.017, max=0.487
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.097, max=0.684
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.021, max=0.545
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.129, max=0.766
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.154, max=0.558
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.123, max=0.433
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.168, max=0.769
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.046, max=0.575
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.070, max=0.439
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.323, max=0.634
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.738
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.169, max=0.480
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=0.580
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.155, max=0.535
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.126, max=0.522
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=0.578
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.118, max=0.492
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.728
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.115, max=0.722
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.088, max=0.629
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.156, max=0.646
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.102, max=0.668
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.109, max=0.332
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.131, max=0.462
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.188, max=0.606
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.168, max=0.432
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.081, max=0.523
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.172, max=0.741
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=0.653
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.107, max=0.673
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.172, max=0.795
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.309, max=0.657
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.035, max=0.556
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.127, max=0.768
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=0.445
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.128, max=0.747
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.231, max=0.768
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.200, max=0.502
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.205, max=0.621
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.115, max=0.518
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.097, max=0.871
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.270, max=0.764
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.066, max=0.828
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.111, max=0.521
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.210, max=0.783
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.201, max=0.633
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.138, max=0.707
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.066, max=0.772
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.177, max=0.971
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.170, max=0.789
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.051, max=0.732
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.082, max=0.715
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.224, max=0.719
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.141, max=0.635
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=0.553
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.038, max=0.723
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.046, max=0.924
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.093, max=0.822
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.118, max=0.882
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=0.711
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.236, max=0.910
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=0.842
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.159, max=0.511
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.178, max=0.726
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.198, max=0.846
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.239, max=0.883
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.011, max=0.782
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.039, max=0.608
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.198, max=0.797
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.203, max=0.706
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.110, max=0.753
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.088, max=0.840
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.238, max=0.820
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.154, max=0.842
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.189, max=0.692
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.082, max=0.794
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.103, max=0.805
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.220, max=0.573
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.147, max=0.507
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=0.784
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.124, max=0.788
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.819
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=0.821
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.153, max=0.841
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.108, max=0.810
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.091, max=0.779
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.169, max=0.780
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.233, max=0.786
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.062, max=0.770
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.081, max=0.469
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.197, max=0.647
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.025, max=0.543
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.036, max=0.859
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.135, max=0.840
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.198, max=0.819
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.447, max=0.940
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/svm_lbp_glcm/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: SVM_LBP_GLCM
#    📁 Arquivo: results/csv_exports/svm_lbp_glcm_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/svm_lbp_glcm_results.csv
# ==================================================
# 'results/csv_exports/svm_lbp_glcm_results.csv'

# %%
print("\n📊 Calculando relevância LBP+LPQ...")
relevance_results_svm_lbp_lpq = relevance_technique(
    base_model=base_svm,
    specialist_sets=final_sp_lbp_lpq_sets,
    class_names=class_names,
    model_name=f"{base_name}-LBP+LPQ",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, svm_lbp_lpq_max_relevances, _, _, _, (svm_lbp_lpq_true_y, svm_lbp_lpq_predicted_y), svm_lbp_lpq_relevance_metrics = relevance_results_svm_lbp_lpq

show_metrics(svm_lbp_lpq_relevance_metrics, title="SVM LBP+LPQ")
show_confusion_matrix(svm_lbp_lpq_true_y, svm_lbp_lpq_predicted_y, title="SVM LBP+LPQ - Confusion Matrix", cmap='Reds')
generate_relevance_heatmaps(
    max_relevances=svm_lbp_lpq_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lbp_lpq",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_svm_lbp_lpq,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LBP_LPQ"
)
# Out:
# 📊 Calculando relevância LBP+LPQ...
# 🚀 Iniciando treinamento de especialistas SVM-LBP+LPQ
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: SVM-LBP+LPQ-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: SVM-LBP+LPQ-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: SVM-LBP+LPQ-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: SVM-LBP+LPQ-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas SVM-LBP+LPQ concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas SVM LBP+LPQ:
#    📊 Acurácia: 88.3333%
#    📊 F1: 88.2844%
#    📊 Recall: 88.3333%
#    📊 Precision: 88.5567%
# ----------------------------------------
# 💾 Matriz de confusão salva em: results/confusion_matrixs/svm_lbp_lpq___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: svm_lbp_lpq
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.016, max=0.570
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.081, max=0.325
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.051, max=0.806
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=0.626
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.278, max=0.851
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.082, max=0.532
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.005, max=0.730
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.094, max=0.885
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.020, max=0.754
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.149, max=0.800
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.220, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.083, max=0.801
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.022, max=0.396
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.137, max=0.726
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.077, max=0.659
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.040, max=0.700
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.159, max=0.842
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=0.514
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.131, max=0.437
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.074, max=0.667
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.021, max=0.660
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.110, max=0.720
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.304, max=0.857
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.059, max=0.845
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.273, max=0.643
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.249, max=0.904
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.044, max=0.721
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.001, max=0.842
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.819
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.332
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.066, max=0.600
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.041, max=0.539
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.099, max=0.435
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.092, max=0.742
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.142, max=0.683
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.183, max=0.623
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.172, max=0.561
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.067, max=0.600
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.528
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.114, max=0.561
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.195, max=0.632
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.198, max=0.677
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.165, max=0.909
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.143, max=0.724
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.118, max=0.798
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.068, max=0.519
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.146, max=0.585
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.212, max=0.919
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.253, max=0.654
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.147, max=0.390
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.147, max=0.399
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.096, max=0.573
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.212, max=0.504
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.106, max=0.764
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.251, max=0.695
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.112, max=0.670
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.080, max=0.637
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.103, max=0.776
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.002, max=0.636
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.168, max=0.689
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=0.866
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.197, max=0.657
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.071, max=0.608
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.164, max=0.483
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.231, max=0.809
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.211, max=0.756
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.223, max=0.883
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.082, max=0.852
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.083, max=0.302
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.210, max=0.579
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.062, max=0.536
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.106, max=0.602
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=0.824
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.163, max=0.379
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.322, max=0.836
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.062, max=0.719
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.015, max=0.607
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.225, max=0.715
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.159, max=0.652
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.152, max=0.692
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.096, max=0.693
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.196, max=0.845
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.009, max=0.681
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.170, max=0.912
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.236, max=0.889
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=0.942
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.152, max=0.833
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.196, max=0.933
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.227, max=0.923
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.244, max=0.919
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.306, max=0.894
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.252, max=0.814
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.071, max=0.932
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.036, max=0.896
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.062, max=0.805
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=0.912
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.125, max=0.803
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.044, max=0.933
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.100, max=0.838
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.301, max=0.847
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.063, max=0.690
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.174, max=0.736
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.071, max=0.737
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.269, max=0.912
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.070, max=0.834
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.279, max=0.960
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.222, max=0.909
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.079, max=0.916
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.063, max=0.960
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=0.923
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.115, max=0.923
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.142, max=0.897
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.103, max=0.796
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.062, max=0.601
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.067, max=0.951
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=0.844
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.035, max=0.661
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.067, max=0.624
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.087, max=0.875
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.263, max=0.702
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/svm_lbp_lpq/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: SVM_LBP_LPQ
#    📁 Arquivo: results/csv_exports/svm_lbp_lpq_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/svm_lbp_lpq_results.csv
# ==================================================
# 'results/csv_exports/svm_lbp_lpq_results.csv'

# %%
print("\n📊 Calculando relevância GLCM+LPQ...")
relevance_results_svm_glcm_lpq = relevance_technique(
    base_model=base_svm,
    specialist_sets=final_sp_glcm_lpq_sets,
    class_names=class_names,
    model_name=f"{base_name}-GLCM+LPQ",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, svm_glcm_lpq_max_relevances, _, _, _, (svm_glcm_lpq_true_y, svm_glcm_lpq_predicted_y), svm_glcm_lpq_relevance_metrics = relevance_results_svm_glcm_lpq

show_metrics(svm_glcm_lpq_relevance_metrics, title="SVM GLCM+LPQ")
show_confusion_matrix(svm_glcm_lpq_true_y, svm_glcm_lpq_predicted_y, title="SVM GLCM+LPQ - Confusion Matrix", cmap='Reds')
generate_relevance_heatmaps(
    max_relevances=svm_glcm_lpq_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_glcm_lpq",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_svm_glcm_lpq,
    true_labels=true_images_labels,
    model_name=f"{base_name}_GLCM_LPQ"
)
# Out:
# 📊 Calculando relevância GLCM+LPQ...
# 🚀 Iniciando treinamento de especialistas SVM-GLCM+LPQ
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: SVM-GLCM+LPQ-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 2e-05, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: SVM-GLCM+LPQ-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: SVM-GLCM+LPQ-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: SVM-GLCM+LPQ-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 2e-05, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas SVM-GLCM+LPQ concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas SVM GLCM+LPQ:
#    📊 Acurácia: 87.5000%
#    📊 F1: 87.4589%
#    📊 Recall: 87.5000%
#    📊 Precision: 87.7966%
# ----------------------------------------
# 💾 Matriz de confusão salva em: results/confusion_matrixs/svm_glcm_lpq___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: svm_glcm_lpq
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.124, max=0.715
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.075, max=0.437
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.044, max=0.822
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.014, max=0.437
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.145, max=0.926
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=0.515
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.141, max=0.852
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.946
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.116, max=0.672
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.203, max=0.742
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.209, max=0.708
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.109, max=0.895
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.094, max=0.333
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.197, max=0.843
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.227, max=0.519
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.051, max=0.572
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.166, max=0.789
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.096, max=0.457
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.321
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.189, max=0.557
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=0.536
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.056, max=0.596
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.199, max=0.909
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.034, max=0.797
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.052, max=0.703
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.224, max=0.704
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.661
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.125, max=0.831
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.024, max=0.847
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.096, max=0.426
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.039, max=0.579
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.049, max=0.705
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.148, max=0.448
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.260, max=0.750
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.109, max=0.636
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.165, max=0.774
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.105, max=0.757
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.066, max=0.526
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.109, max=0.613
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.236, max=0.621
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.226, max=0.801
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.155, max=0.755
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.155, max=0.922
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.103, max=0.796
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.116, max=0.678
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.085, max=0.664
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=0.555
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.207, max=0.823
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.315, max=0.683
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.214, max=0.570
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.126, max=0.369
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.136, max=0.680
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.149, max=0.498
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.131, max=0.556
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.090, max=0.568
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.196, max=0.680
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.041, max=0.513
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.094, max=0.665
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.016, max=0.687
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.487, max=0.809
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.099, max=0.903
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.208, max=0.636
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=0.611
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.134, max=0.677
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.293, max=0.883
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.272, max=0.766
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.111, max=0.860
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.075, max=0.862
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.068, max=0.480
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.230, max=0.492
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.707
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.403
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.112, max=0.812
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.100, max=0.793
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.111, max=0.890
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=0.234
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.021, max=0.425
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.176, max=0.819
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.150, max=0.746
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.079, max=0.842
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.161, max=0.885
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.200, max=0.866
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.791
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.105, max=0.924
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.205, max=0.924
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.095, max=0.914
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.029, max=0.813
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.007, max=0.899
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.083, max=0.946
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.925
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.308, max=0.927
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.152, max=0.791
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.198, max=0.924
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.084, max=0.799
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.131, max=0.790
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.026, max=0.878
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.125, max=0.623
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.176, max=0.948
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.118, max=0.851
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=0.871
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.091, max=0.775
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.250, max=0.645
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.136, max=0.790
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.164, max=0.916
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.122, max=0.597
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.111, max=0.941
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.155, max=0.817
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.103, max=0.949
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.116, max=0.939
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.108, max=0.957
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.144, max=0.766
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.053, max=0.734
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.047, max=0.779
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.048, max=0.529
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.177, max=0.944
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.094, max=0.845
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.037, max=0.681
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.045, max=0.889
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.219, max=0.835
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.187, max=0.823
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/svm_glcm_lpq/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: SVM_GLCM_LPQ
#    📁 Arquivo: results/csv_exports/svm_glcm_lpq_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/svm_glcm_lpq_results.csv
# ==================================================
# 'results/csv_exports/svm_glcm_lpq_results.csv'

# %%
print("\n📊 Calculando relevância LBP+GLCM+LPQ...")
relevance_results_svm_lbp_glcm_lpq = relevance_technique(
    base_model=base_svm,
    specialist_sets=final_sp_lbp_glcm_lpq_sets,
    class_names=class_names,
    model_name=f"{base_name}-LBP+GLCM+LPQ",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, svm_lbp_glcm_lpq_max_relevances, _, _, _, (svm_lbp_glcm_lpq_true_y, svm_lbp_glcm_lpq_predicted_y), svm_lbp_glcm_lpq_relevance_metrics = relevance_results_svm_lbp_glcm_lpq

show_metrics(svm_lbp_glcm_lpq_relevance_metrics, title="SVM LBP+GLCM+LPQ")
show_confusion_matrix(svm_lbp_glcm_lpq_true_y, svm_lbp_glcm_lpq_predicted_y, title="SVM LBP+GLCM+LPQ - Confusion Matrix", cmap='Reds')
generate_relevance_heatmaps(
    max_relevances=svm_lbp_glcm_lpq_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lbp_glcm_lpq",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_svm_lbp_glcm_lpq,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LBP_GLCM_LPQ"
)
# Out:
# 📊 Calculando relevância LBP+GLCM+LPQ...
# 🚀 Iniciando treinamento de especialistas SVM-LBP+GLCM+LPQ
#    📋 4 especialistas para treinar
#    🔄 Validação cruzada: 5 folds
# ------------------------------------------------------------
#
# 🎯 Treinando especialista 1/4: dogs
# === Iniciando treinamento assistido: SVM-LBP+GLCM+LPQ-Specialist-dogs ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 1000, 'svm__gamma': 2e-05, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 2/4: cats
# === Iniciando treinamento assistido: SVM-LBP+GLCM+LPQ-Specialist-cats ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 3/4: lions
# === Iniciando treinamento assistido: SVM-LBP+GLCM+LPQ-Specialist-lions ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎯 Treinando especialista 4/4: horses
# === Iniciando treinamento assistido: SVM-LBP+GLCM+LPQ-Specialist-horses ===
# Validação cruzada: 5 folds
# --------------------------------------------------
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# Melhores parâmetros: {'svm__C': 100, 'svm__gamma': 0.002, 'svm__kernel': 'rbf'}
# --------------------------------------------------
#
# 🎉 Treinamento de especialistas SVM-LBP+GLCM+LPQ concluído!
#    ✅ 4 especialistas treinados com sucesso
#    📦 Array retornado: raw_probabilities[i] = probabilidades do especialista da classe i
# ============================================================
# ----------------------------------------
# Métricas SVM LBP+GLCM+LPQ:
#    📊 Acurácia: 90.8333%
#    📊 F1: 90.8173%
#    📊 Recall: 90.8333%
#    📊 Precision: 91.1331%
# ----------------------------------------
# 💾 Matriz de confusão salva em: results/confusion_matrixs/svm_lbp_glcm_lpq___confusion_matrix_confusion_matrix.png
# 🎨 Gerando heatmaps de relevância para modelo: svm_lbp_glcm_lpq
#    📊 Colormap: rainbow
#    🎭 Transparência overlay: 0.5
#    🔲 Linhas de grade: True
# ------------------------------------------------------------
#    ✅ 120 imagens serão processadas
#    🔄 Processando cat1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.219, max=0.755
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.004, max=0.444
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.035, max=0.742
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.101, max=0.527
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.253, max=0.885
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.060, max=0.594
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.016, max=0.768
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.159, max=0.923
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.012, max=0.645
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.220, max=0.739
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.290, max=0.731
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.064, max=0.768
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.048, max=0.310
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.192, max=0.797
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.149, max=0.650
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.690
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.133, max=0.848
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.064, max=0.534
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.229, max=0.299
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.116, max=0.562
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.034, max=0.710
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.077, max=0.720
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.320, max=0.858
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.123, max=0.819
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=0.739
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.274, max=0.810
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.022, max=0.626
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.166, max=0.950
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.078, max=0.818
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando cat9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.048, max=0.517
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog1: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.044, max=0.709
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog10: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.056, max=0.759
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog11: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.155, max=0.389
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog12: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.277, max=0.854
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog13: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.137, max=0.633
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog14: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.205, max=0.739
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog15: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.142, max=0.568
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog16: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.148, max=0.865
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog17: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.072, max=0.626
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.285, max=0.614
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog19: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.250, max=0.622
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog2: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.119, max=0.596
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog20: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.160, max=0.919
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.150, max=0.813
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog22: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.155, max=0.774
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog23: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.109, max=0.686
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog24: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.119, max=0.640
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog25: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.222, max=0.910
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog26: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.263, max=0.708
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog27: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.153, max=0.537
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog28: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.232, max=0.306
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog29: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.102, max=0.749
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog3: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.222, max=0.592
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog30: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.202, max=0.750
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog4: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.241, max=0.633
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog5: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.214, max=0.819
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog6: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.058, max=0.586
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog7: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.163, max=0.804
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog8: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.008, max=0.751
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando dog9: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.397, max=0.812
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1248: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.077, max=0.891
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1483: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.241, max=0.810
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse1731: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.062, max=0.612
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse18: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.109, max=0.534
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2049: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.280, max=0.924
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2055: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.230, max=0.824
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2057: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.107, max=0.873
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2062: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.134, max=0.800
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2063: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.052, max=0.538
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse21: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.237, max=0.659
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2242: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.060, max=0.787
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2398: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.076, max=0.651
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2682: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.069, max=0.615
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.083, max=0.570
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2697: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.218, max=0.868
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2705: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.062, max=0.673
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2708: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=0.358
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse2709: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.187, max=0.777
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse346: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.183, max=0.702
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse381: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.104, max=0.891
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse456: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.147, max=0.890
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse460: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.246, max=0.899
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse470: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.089, max=0.830
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse728: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.125, max=0.923
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse764: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.255, max=0.960
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse796: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.064, max=0.925
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse843: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.091, max=0.846
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse877: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.057, max=0.909
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse883: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.232, max=0.980
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando horse887: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.146, max=0.978
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1035: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.322, max=0.928
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1696: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.251, max=0.849
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1892: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.209, max=0.968
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1894: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.042, max=0.924
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1896: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.061, max=0.773
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1901: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.010, max=0.916
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1904: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.244, max=0.854
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1908: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.031, max=0.932
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1921: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.191, max=0.870
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1927: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.416, max=0.910
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1932: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.067, max=0.714
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1933: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.211, max=0.832
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1934: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.162, max=0.787
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion1945: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.201, max=0.937
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2236: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.081, max=0.757
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2255: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.194, max=0.934
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2267: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.213, max=0.931
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2312: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.199, max=0.951
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2318: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.213, max=0.946
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2324: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.075, max=0.945
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2341: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.155, max=0.921
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2377: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.133, max=0.944
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2647: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.135, max=0.845
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2652: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.030, max=0.395
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2654: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.212, max=0.947
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2661: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.065, max=0.857
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion2679: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.088, max=0.344
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion274: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.050, max=0.903
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion42: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.146, max=0.793
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#    🔄 Processando lion738: grade 3x3 = 9 segmentos
#        Relevâncias: min=0.263, max=0.814
# Reconstructing image from regions...
#        🔲 Linhas de grade adicionadas
# Reconstructing image from regions...
#        💾 Salvo com sucesso
#        🎨 Heatmap final: (512, 512, 3) (altura, largura, RGB)
#        🎭 Overlay criado com transparência: 0.5
#
# 🎉 CONCLUÍDO: 120 heatmaps de relevância gerados!
#    📁 Salvos em: results/svm_lbp_glcm_lpq/overlays/
#    🎨 Colormap: rainbow
#    🎭 Transparência: 0.5
#    🔲 Linhas de grade: Ativadas
# ============================================================
# 📊 Exportando resultados para CSV: SVM_LBP_GLCM_LPQ
#    📁 Arquivo: results/csv_exports/svm_lbp_glcm_lpq_results.csv
#    🎯 Imagens: 120 amostras
# --------------------------------------------------
#    ✅ 120 linhas escritas com sucesso
#    💾 Arquivo salvo: results/csv_exports/svm_lbp_glcm_lpq_results.csv
# ==================================================
# 'results/csv_exports/svm_lbp_glcm_lpq_results.csv'

# %%
print("✅ Relevância calculada para todos os 7 conjuntos de features")
print("📊 Métricas e matrizes de confusão geradas para cada combinação")
print("\n🎉 === CÁLCULO DE RELEVÂNCIA SVM CONCLUÍDO ===")
# Out:
# ✅ Relevância calculada para todos os 7 conjuntos de features
# 📊 Métricas e matrizes de confusão geradas para cada combinação
#
# 🎉 === CÁLCULO DE RELEVÂNCIA SVM CONCLUÍDO ===

# %% [markdown]
# ## Random Forest

# %%
print("🚀 === CALCULANDO RELEVÂNCIA DOS MODELOS RF ===")

class_names = image_categories
base_name = 'RF'

print("\n📊 Calculando relevância LBP...")
relevance_results_rf_lbp = relevance_technique(
    base_model=base_rf,
    specialist_sets=final_sp_lbp_sets,
    class_names=class_names,
    model_name=f"{base_name}-LBP",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, rf_lbp_max_relevances, _, _, _, (rf_lbp_true_y, rf_lbp_predicted_y), rf_lbp_relevance_metrics = relevance_results_rf_lbp

show_metrics(rf_lbp_relevance_metrics, title=f"{base_name} LBP")
show_confusion_matrix(rf_lbp_true_y, rf_lbp_predicted_y, title=f"{base_name} LBP - Confusion Matrix", cmap='Greens')
generate_relevance_heatmaps(
    max_relevances=rf_lbp_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lbp",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_rf_lbp,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LBP"
)

# %%
print("\n📊 Calculando relevância GLCM...")
relevance_results_rf_glcm = relevance_technique(
    base_model=base_rf,
    specialist_sets=final_sp_glcm_sets,
    class_names=class_names,
    model_name=f"{base_name}-GLCM",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, rf_glcm_max_relevances, _, _, _, (rf_glcm_true_y, rf_glcm_predicted_y), rf_glcm_relevance_metrics = relevance_results_rf_glcm

show_metrics(rf_glcm_relevance_metrics, title=f"{base_name} GLCM")
show_confusion_matrix(rf_glcm_true_y, rf_glcm_predicted_y, title=f"{base_name} GLCM - Confusion Matrix", cmap='Greens')
generate_relevance_heatmaps(
    max_relevances=rf_glcm_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_glcm",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_rf_glcm,
    true_labels=true_images_labels,
    model_name=f"{base_name}_GLCM"
)

# %%
print("\n📊 Calculando relevância LPQ...")
relevance_results_rf_lpq = relevance_technique(
    base_model=base_rf,
    specialist_sets=final_sp_lpq_sets,
    class_names=class_names,
    model_name=f"{base_name}-LPQ",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, rf_lpq_max_relevances, _, _, _, (rf_lpq_true_y, rf_lpq_predicted_y), rf_lpq_relevance_metrics = relevance_results_rf_lpq

show_metrics(rf_lpq_relevance_metrics, title=f"{base_name} LPQ")
show_confusion_matrix(rf_lpq_true_y, rf_lpq_predicted_y, title=f"{base_name} LPQ - Confusion Matrix", cmap='Greens')
generate_relevance_heatmaps(
    max_relevances=rf_lpq_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lpq",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_rf_lpq,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LPQ"
)

# %%
print("\n📊 Calculando relevância LBP+GLCM...")
relevance_results_rf_lbp_glcm = relevance_technique(
    base_model=base_rf,
    specialist_sets=final_sp_lbp_glcm_sets,
    class_names=class_names,
    model_name=f"{base_name}-LBP+GLCM",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, rf_lbp_glcm_max_relevances, _, _, _, (rf_lbp_glcm_true_y, rf_lbp_glcm_predicted_y), rf_lbp_glcm_relevance_metrics = relevance_results_rf_lbp_glcm

show_metrics(rf_lbp_glcm_relevance_metrics, title=f"{base_name} LBP+GLCM")
show_confusion_matrix(rf_lbp_glcm_true_y, rf_lbp_glcm_predicted_y, title=f"{base_name} LBP+GLCM - Confusion Matrix", cmap='Greens')
generate_relevance_heatmaps(
    max_relevances=rf_lbp_glcm_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lbp_glcm",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_rf_lbp_glcm,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LBP_GLCM"
)

# %%
print("\n📊 Calculando relevância LBP+LPQ...")
relevance_results_rf_lbp_lpq = relevance_technique(
    base_model=base_rf,
    specialist_sets=final_sp_lbp_lpq_sets,
    class_names=class_names,
    model_name=f"{base_name}-LBP+LPQ",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, rf_lbp_lpq_max_relevances, _, _, _, (rf_lbp_lpq_true_y, rf_lbp_lpq_predicted_y), rf_lbp_lpq_relevance_metrics = relevance_results_rf_lbp_lpq

show_metrics(rf_lbp_lpq_relevance_metrics, title=f"{base_name} LBP+LPQ")
show_confusion_matrix(rf_lbp_lpq_true_y, rf_lbp_lpq_predicted_y, title=f"{base_name} LBP+LPQ - Confusion Matrix", cmap='Greens')
generate_relevance_heatmaps(
    max_relevances=rf_lbp_lpq_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lbp_lpq",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_rf_lbp_lpq,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LBP_LPQ"
)

# %%
print("\n📊 Calculando relevância GLCM+LPQ...")
relevance_results_rf_glcm_lpq = relevance_technique(
    base_model=base_rf,
    specialist_sets=final_sp_glcm_lpq_sets,
    class_names=class_names,
    model_name=f"{base_name}-GLCM+LPQ",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, rf_glcm_lpq_max_relevances, _, _, _, (rf_glcm_lpq_true_y, rf_glcm_lpq_predicted_y), rf_glcm_lpq_relevance_metrics = relevance_results_rf_glcm_lpq

show_metrics(rf_glcm_lpq_relevance_metrics, title=f"{base_name} GLCM+LPQ")
show_confusion_matrix(rf_glcm_lpq_true_y, rf_glcm_lpq_predicted_y, title=f"{base_name} GLCM+LPQ - Confusion Matrix", cmap='Greens')
generate_relevance_heatmaps(
    max_relevances=rf_glcm_lpq_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_glcm_lpq",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_rf_glcm_lpq,
    true_labels=true_images_labels,
    model_name=f"{base_name}_GLCM_LPQ"
)

# %%
print("\n📊 Calculando relevância LBP+GLCM+LPQ...")
relevance_results_rf_lbp_glcm_lpq = relevance_technique(
    base_model=base_rf,
    specialist_sets=final_sp_lbp_glcm_lpq_sets,
    class_names=class_names,
    model_name=f"{base_name}-LBP+GLCM+LPQ",
    k_folds=K_FOLDS,
    true_labels=true_images_labels
)

_, _, _, rf_lbp_glcm_lpq_max_relevances, _, _, _, (rf_lbp_glcm_lpq_true_y, rf_lbp_glcm_lpq_predicted_y), rf_lbp_glcm_lpq_relevance_metrics = relevance_results_rf_lbp_glcm_lpq

show_metrics(rf_lbp_glcm_lpq_relevance_metrics, title=f"{base_name} LBP+GLCM+LPQ")
show_confusion_matrix(rf_lbp_glcm_lpq_true_y, rf_lbp_glcm_lpq_predicted_y, title=f"{base_name} LBP+GLCM+LPQ - Confusion Matrix", cmap='Greens')
generate_relevance_heatmaps(
    max_relevances=rf_lbp_glcm_lpq_max_relevances,
    all_images_segmented=all_images_segmented,
    model_name=f"{base_name.lower()}_lbp_glcm_lpq",
    overlay_alpha=0.5,
    save_grid_lines=True,
    colormap='rainbow'
)

# Exporta resultados para CSV
export_relevance_results_to_csv(
    relevance_results=relevance_results_rf_lbp_glcm_lpq,
    true_labels=true_images_labels,
    model_name=f"{base_name}_LBP_GLCM_LPQ"
)

# %%
print("✅ Relevância calculada para todos os 7 conjuntos de features")
print("📊 Métricas e matrizes de confusão geradas para cada combinação")
print("\n🎉 === CÁLCULO DE RELEVÂNCIA RF CONCLUÍDO ===")
